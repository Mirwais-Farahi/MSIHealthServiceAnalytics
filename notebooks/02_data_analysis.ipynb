# %% [markdown]
# ## Descriptive Anlytics
# - Client Exit Interviews (CEIs), the goal is to summarize and visualize key characteristics of the data.

# %% [markdown]
# ### 1. Import Libraries

# %%
# Import libs
# from google.colab import files
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import statsmodels.api as sm
import sys

sys.path.append('../src')
from utils import load_data, summary_percentage_table, display
from viz import plot_vertical_bar_chart, plot_distribution, plot_bar_chart_with_percentage, calculate_percentage_table

# Colors
colors = ['#005055', '#64afa0', '#6ec34b', '#198cc3']

# Channels
channels = ['MSI centre', 'Outreach', 'MS Lady']

# %% [markdown]
# ### 2. Load the Dataset

# %%
# Maximum Display for data
display()
# Out:
# Display All Columns Feature Activated

# %%
# load the CEI dataset
data_file_path = '../data/processed/MSIA_2024_CEI_Afghanistan_data_cleaned.csv'
data = load_data(data_file_path)

# %%
# Read labels stata file
itr = pd.read_stata('../data/raw/MSI_2024_CEI_Afghanistan.dta', iterator=True)
itr.variable_labels()
# Out:
# {'starttime': 'starttime',
#  'endtime': 'endtime',
#  'deviceid': 'deviceid',
#  'devicephonenum': 'devicephonenum',
#  'subscriberid': 'subscriberid',
#  'simid': 'simid',
#  'DATAUSE': 'Client consent for sharing anonymous data',
#  'DATE': "Enter today's date",
#  'FACTYPE': 'Type of facility or site',
#  'NAME_C': 'Enter the name of the Centre',
#  'NAME_OR': 'Enter the name of the Outreach site',
#  'NAME_SF': 'Enter the name of the Social Franchise',
#  'NAME_MSL': 'Enter the name of the MS Lady/ site',
#  'NAME_PSS': 'Enter the name of the PSS site',
#  'NAME_OTH': 'Enter the name of the site',
#  'REGION': 'Enter facility/site region',
#  'LOCATION': 'Enter type of location',
#  'TR2DH': 'How long did it take you to travel here today? Hours',
#  'TR2DM': 'How long did it take you to travel here today? Minutes',
#  'FPTYPE': 'FPTYPE',
#  'FPTYPEFPMETH': 'Contraception: Contraceptive method(s) received',
#  'FPTYPEFPREM': 'Contraception: Contraceptive method removed',
#  'FPTYPEFPNO': 'Contraception: No contraceptive method received or removed',
#  'FPTYPEFPDK': "Contraception: Don't know",
#  'FPTYPEFPREF': 'Contraception: Refused',
#  'FPreceived': 'Type of Family Planning method receieved',
#  'FSTER': 'Received Female sterilisation/tubal ligation',
#  'MSTER': 'Received Male sterilisation/vasectomy',
#  'IUD': 'Received Intra-uterine system or device',
#  'IMP': 'Received Implant',
#  'INJ': 'Received Injectable contraception',
#  'OC': 'Received Contraceptive pills, non-emergency',
#  'MC': 'Received Male condoms',
#  'FC': 'Received Female condoms',
#  'EC': 'Received Emergency contraceptive pill',
#  'OMM': 'Received Other modern method - diaphragm, foam tablets, spermicidal jelly, vagin',
#  'REF': 'Refused',
#  'calculation_FP': 'calculation_FP',
#  'AVAIL_FP': 'For the FP service you received today, do you know of another provider offering ',
#  'REMOPTS': 'Were you told where you could go to have your method removed?',
#  'calculation_FPREM': 'calculation_FPREM',
#  'REMWHY': 'Why did you have this family planning method removed?',
#  'FPREMSIDE': 'Can you please tell me what side-effects you experienced?',
#  'RCYCLE': 'Changes to menstrual cycle',
#  'RINFECT': 'Pain or infection',
#  'RMOOD': 'Mood Changes',
#  'RHLTH': 'Health concerns',
#  'RWEIGHT': 'Weight gain',
#  'RSIDEOTH': 'No other removal side effects',
#  'RSIDEREF': 'Refused (FPREMSIDE)',
#  'REMWHERE': 'For the method you had removed today, where did you have this method inserted?',
#  'PAIN_REM': 'Did the provider explain to you the possibility of experiencing pain during your',
#  'PAINMAN_REM': 'Did the provider explain different options to manage the pain throughout the pro',
#  'PAINOP_IMPREM': 'What options were explained to you?',
#  'PAINOP_IMPREM1': 'Local anaesthesia',
#  'PAINOP_IMPREM2': 'Medication for anxiety',
#  'PAINOP_IMPREM3': 'Vocal local',
#  'PAINOP_IMPREM666': 'Other',
#  'PAINOP_IMPREM999': "Don't know",
#  'PAINOP_IMPREM888': 'Refused',
#  'PAINOP_IUDREM': 'What options were explained to you?',
#  'PAINOP_IUDREM1': 'Oral analgesics',
#  'PAINOP_IUDREM2': 'Local cream/spray on cervix',
#  'PAINOP_IUDREM3': 'Paracervical block (injection next to the cervix)',
#  'PAINOP_IUDREM4': 'Vocal local',
#  'PAINOP_IUDREM666': 'Other',
#  'PAINOP_IUDREM999': "Don't know",
#  'PAINOP_IUDREM888': 'Refused',
#  'MEDBEF_REM': 'Were you offered pain medication before the procedure?',
#  'PAINSCALE_DREM': 'From 0-10, what was your pain during the procedure?',
#  'PAINDUR_REM': 'Were you asked about pain during the procedure?',
#  'MEDDUR_REM': 'Were you offered pain medication during the procedure?',
#  'PAINSCALE_AREM': 'From 0-10, what was your pain after the procedure?',
#  'PAINAFT_REM': 'Were you asked about pain after the procedure?',
#  'MEDAFT_REM': 'Were you offered pain medication after the procedure?',
#  'PAINRES_REM': 'Did you feel that the provider was respectful and responsive to your pain?',
#  'servicereceived': 'What service(s) did you receive today?',
#  'SAC': 'Safe abortion / post-abortion care',
#  'FPCounsel': 'Contraceptive counselling',
#  'PTEST': 'Pregnancy test',
#  'HIV': 'HIV testing/treatment',
#  'STI': 'Other STI testing/ treatment',
#  'CCS': 'Cervical cancer screening/treatment',
#  'MCH': 'Received general maternal/child health service',
#  'GEN': 'Received General health consultation',
#  'OTHSRH': 'Received Other SRH service',
#  'OTHGEN': 'Received Other general health service',
#  'ADDNONE': 'None',
#  'ADDREF': 'Refused',
#  'ANC_C': 'Antenatal care (centres only)',
#  'DELC_C': 'Delivery care (centres only)',
#  'PNC_C': 'Postnatal care (centres only)',
#  'SACTYPE': 'What method of abortion or post-abortion care did you have or begin today?',
#  'calculation_SAC': 'calculation_SAC',
#  'Service_Received': 'Service_Received',
#  'FPEVER': 'Have you ever used a method of contraception before today?',
#  'FPWANT': 'Do you currently want to be using any method of contraception?',
#  'FPCURR': 'Have you or your partner used any method of contraception during the past 3 mont',
#  'CMETH': 'What was the main method of contraception that you were using in the past 3 mont',
#  'Prev_FPmethod': 'Prev_FPmethod',
#  'FPWHERE': 'Prior to your visit today, where did you get the method that you were using most',
#  'CMADD': 'Have you or your partner/s used any additional methods of contraception in the p',
#  'CMADDMTH': 'Please specify all additional method/s of contraception you or your partner/s ha',
#  'CMADDMTH1': 'Female sterilisation',
#  'CMADDMTH2': 'Male sterilisation',
#  'CMADDMTH3': 'IUD/IUS',
#  'CMADDMTH4': 'Implants',
#  'CMADDMTH5': 'Injectables',
#  'CMADDMTH6': 'Contraceptive pills',
#  'CMADDMTH7': 'Male condoms',
#  'CMADDMTH8': 'Female condoms',
#  'CMADDMTH9': 'Emergency contraception',
#  'CMADDMTH10': 'Breast-feeding: lactational amenorrhea method',
#  'CMADDMTH11': 'Other modern method: diaphragm, foam tablets, spermicidal jelly, vaginal ring, c',
#  'CMADDMTH12': 'Traditional methods: Fertility awareness, calendar (rhythm), withdrawal, abstine',
#  'CMADDMTH888': 'Refused',
#  'CMCURWNT': 'Prior to your visit today, did you want to be using the method?',
#  'CMACCESS': 'You said that you sometimes use this method. Have there been times that you want',
#  'COUNSEL_PAFP': 'Did the provider counsel you on your options for contraception use following you',
#  'WNTMETH': 'When you came here today, did you want to receive a method of contraception from',
#  'SPCMTH': 'When you came here today, was there a specific FP method you wanted to get?',
#  'WAMETH': 'Which method did you want to get when you came here today?',
#  'RECMETH': 'Did you receive a method of contraception, or a referral to receive a method of ',
#  'CHMETH': 'Did you receive the method you wanted, or a referral for the method you wanted?',
#  'METHNO': "What was the main reason you didn't receive a method or a referral for a method ",
#  'METHDIFF': "What was the main reason why you didn't receive the method that you wanted?",
#  'CMREASON': 'You mentioned that you did not want or weren’t sure if you wanted a method of co',
#  'RECCOUN': 'Did the provider tell you about any potential side effects or problems you may e',
#  'FOLLUP': 'Were you told what to do if you experience any side effects or problems as a res',
#  'CONTUSE': 'Were you told about the possibility of switching to another method if the method',
#  'OTHERMETH': 'Were you told by the provider about other methods of contraception besides the c',
#  'TOLDABOUT': 'TOLDABOUT',
#  'CHFSTER': 'Female sterilisation',
#  'CHMSTER': 'Male sterilisation',
#  'CHIUD': 'IUD',
#  'CHIMP': 'Implants',
#  'CHINJ': 'Injectables',
#  'CHOCP': 'Contraceptive pills',
#  'CHMC': 'Male condoms',
#  'CHFC': 'Female condoms',
#  'CHEC': 'Emergency contraception',
#  'CHLAM': 'Breast-feeding: lactational amenorrhea method',
#  'CHOMM': 'Other modern method: diaphragm, foam tablets, spermicidal jelly, vaginal ring, c',
#  'CHTRAD': 'Traditional methods: Fertility awareness, calendar (rhythm), withdrawal, abstine',
#  'CHDK': "Don't know",
#  'CMAUTO': 'On a scale of 0 to 10, how important do you think the service(s) you received to',
#  'IMPACT': 'Do you feel that the service(s) you received today will have a positive impact o',
#  'IMPEDU': 'Education (continue education, return to education, support a child through scho',
#  'IMPWRK': 'Work (continue to work, return to work, progress in work)',
#  'IMPFAM': 'Family (support family, increased resources for family, manage family)',
#  'IMPHLTH': 'Health (better personal health, better family health)',
#  'IMPOTH': 'Other',
#  'IMPNONE': 'None',
#  'IMPDK': "Don't know",
#  'IMPREF': 'Refused',
#  'REC': 'Based on your experience today, how likely are you to recommend our services to ',
#  'RET': 'Based on your experience today, if you needed a similar service in the future, h',
#  'PRIV': 'I had enough privacy during my visit today',
#  'REST': 'I was treated with respect by all staff during my visit today',
#  'WAIT': 'The time I waited to see a provider today was acceptable',
#  'CARE': 'The provider was easy to understand ',
#  'ENOUGH': 'The provider gave me enough information to make the best decisions about my meth',
#  'SERIOUS': 'The provider took my preferences seriously ',
#  'RPRT': 'The provider gave me the opportunity to explain my needs and ask questions ',
#  'COMFORT': 'All staff members made me comfortable during my visit today',
#  'GEN_SAT': 'Overall, how satisfied are you with your experience with us today?',
#  'HOURS': 'Was it clear to you what hours the facility was open/when you could come in to r',
#  'FEED': 'Were you informed on how to give feedback or complain about your experience toda',
#  'PRIVINFO': 'Do you trust the provider to keep your personal information private?',
#  'PAIN_CM': 'Did the provider explain to you the possibility of experiencing pain during your',
#  'PAINMAN_CM': 'Did the provider explain different options to manage the pain throughout the pro',
#  'PAINOP_IMP': 'What options were explained to you?',
#  'PAINOP_IMP1': 'Local anaesthesia',
#  'PAINOP_IMP2': 'Medication for anxiety',
#  'PAINOP_IMP3': 'Vocal local',
#  'PAINOP_IMP666': 'Other',
#  'PAINOP_IMP999': "Don't know",
#  'PAINOP_IMP888': 'Refused',
#  'PAINOP_IUD': 'What options were explained to you?',
#  'PAINOP_IUD1': 'Oral analgesics',
#  'PAINOP_IUD2': 'Local cream/spray on cervix',
#  'PAINOP_IUD3': 'Paracervical block (injection next to the cervix)',
#  'PAINOP_IUD4': 'Vocal local',
#  'PAINOP_IUD666': 'Other',
#  'PAINOP_IUD999': "Don't know",
#  'PAINOP_IUD888': 'Refused',
#  'MEDBEF_CM': 'Were you offered pain medication before the procedure?',
#  'PAINSCALE_DCM': 'From 0-10, what was your pain during the procedure?',
#  'PAINDUR_CM': 'Were you asked about pain during the procedure?',
#  'MEDDUR_CM': 'Were you offered pain medication during the procedure?',
#  'PAINSCALE_ACM': 'From 0-10, what was your pain after the procedure?',
#  'PAINAFT_CM': 'Were you asked about pain after the procedure?',
#  'MEDAFT_CM': 'Were you offered pain medication after the procedure?',
#  'PAINRES_CM': 'Did you feel that the provider was respectful and responsive to your pain?',
#  'INFO': 'Did any of the following play a part in making you aware of the services you rec',
#  'IADVERT': 'TV advert or programme',
#  'IRADIO': 'Radio advert or programme',
#  'INEWS': 'Newspaper/ magazine',
#  'IMEET': 'Community meeting or event',
#  'INET': 'Website/ google',
#  'ISOCMED': 'Social media',
#  'ISIGN': 'Outdoor sign',
#  'ISPKR': 'Loudspeaker',
#  'IPRMAT': 'Posters/ leaflets / flyers',
#  'MSAFG_IRELG': 'Religious Leaders/Groups',
#  'INFOOTH': 'Other',
#  'INFONO': 'None',
#  'AWRTIME': 'How long ago did you become aware that MSI would be providing these services at ',
#  'REFER': 'Did anyone refer you to, or recommend, that you visit this site or provider toda',
#  'RCBM': 'Community based mobiliser',
#  'RPUBPROV': 'Provider/ staff member at a public health facility',
#  'RPRIVPROV': 'Provider/ staff member at a private health facility',
#  'RREFU': 'Friend/ family member who has used MSI services',
#  'RREFNU': 'Friend/ family member who has not used MSI services',
#  'REFNONE': 'None',
#  'CCUSE_BEF': 'Did you speak to the MSI contact centre through phone or messaging at any point ',
#  'CELLOWN': 'Do you have your own cell phone?',
#  'POSIPC': 'In my community, I hear positive stories about using contraception',
#  'KSANCTION': 'In my community, women are stigmatised if people know that they use contraceptio',
#  'KMENSUPP': 'In my community, most men are supportive of their partner(s) using contraception',
#  'KCOMSUPP': 'In my community, using modern contraception is accepted',
#  'KLEADSUP': 'In my community, local leaders encourage the use of contraception',
#  'FPDECMAK': 'Who usually makes decisions about any methods of contraception for yourself?',
#  'GENDER': "Enter respondent's gender",
#  'AGE': 'How old are you?',
#  'EDU': 'What is your highest level of education?',
#  'MAR': 'What is your marital status?',
#  'CHILD': 'How many living children do you have?',
#  'PPART': 'When did you last give birth?',
#  'IDEALFS': 'What is your ideal number of children?',
#  'JOB': 'What is your current occupation?',
#  'DISPLACED': 'Have you ever been forced or obliged to leave your place of origin to relocate t',
#  'WHERE_DISP': 'Where did you move from and where did you move to?',
#  'WHY_DISPA': 'If you feel comfortable, can you share the main reason for leaving your country ',
#  'WHY_DISPB': 'I will read out some reasons to you, can you please let me know what your main r',
#  'DIS1': 'Do you have difficulty seeing?',
#  'DIS2': 'Do you have difficulty hearing?',
#  'DIS3': 'Do you have difficulty sitting, standing, walking or climbing steps?',
#  'DIS4': 'Do you have difficulty remembering or concentrating?',
#  'DIS5': 'Do you have difficulty with self-care?',
#  'DIS6': 'Using your usual language, do you have difficulty communicating?',
#  'MPI_YS': 'Have any household members completed 6 years or more of schooling?',
#  'MPI_SCA': 'Are all household members aged 5-13 currently attending school [or, during schoo',
#  'MPI_CM': 'Has a household member under 18 died in your household in the past five-years?',
#  'MPI_FLR': 'Thinking of your home, what is the main material of your floor?',
#  'MPI_WALL': 'Thinking of your home, what is the main material of your walls?',
#  'MPI_ROOF': 'Thinking of your home, what is the main material of your roof?',
#  'MPI_TOSHR': 'Is the toilet or latrine shared with other households?',
#  'MPI_TO': 'What kind of toilet facility do members of your household usually use?',
#  'MPI_CF': 'What type of fuel does your household mainly use for cooking?',
#  'MPI_WATDIS': 'How long does it take to get to your drinking water source, get water and come b',
#  'MPI_WAT': 'What is the source of drinking water in your household?',
#  'MPI_ELEC': 'Do you have electricity at home?',
#  'MPI_TRUCK': 'Does your household own a car or truck?',
#  'MPI_ASSETS': 'Does your household own more than one of the following assets?  Telephone, radio',
#  'unique_id1': 'unique_id1',
#  'unique_id2': 'unique_id2',
#  'unique_id3': 'unique_id3',
#  'unique_id4': 'unique_id4',
#  'unique_id5': 'unique_id5',
#  'NUMBERQ': 'NUMBERQ',
#  '_id': '_id',
#  '_uuid': '_uuid',
#  '_submission_time': '_submission_time',
#  '_validation_status': '_validation_status',
#  '_notes': '_notes',
#  '_status': '_status',
#  '_submitted_by': '_submitted_by',
#  '__version__': '__version__',
#  '_tags': '_tags',
#  '_index': '_index',
#  'FPREMTYPE': 'Which contraceptive method did you have removed today?',
#  'CCREAS_BEF': 'What was your main reason for speaking to the contact centre?',
#  'id': '',
#  'FPREM': 'Did you have a family planning method removed today?',
#  'FP': 'Client received a family planning service',
#  'FPMETHUNK': '',
#  'MSP': 'Marie Stopes procedure',
#  'MSMP': 'Marie Stopes medical procedure',
#  'CHOICEtot': 'Number of modern methods counseled on',
#  'CHOICEtotAllMethods': 'Number of methods counseled on (including trad methods)',
#  'othermeth_calc': 'Clients counselled on at least one alternative FP method',
#  'filterPAIN': 'FILTER - All clients receiving a service that might have involved pain',
#  'filterPAIN_FPMSP': 'Client received painful procedure (FP / MSP)',
#  'filterPAINFP': 'Client received painful FP procedure',
#  'NINFO': 'Number of sources that influenced client to come to MSI',
#  'ENUMID': 'group(ENUMID2)',
#  'FPREC': 'Did the client receive an FP method?',
#  'REMCLIENTONLY': 'Clients that only got a removal and no other FP service',
#  'SACLIENT': 'Did the client receive SA/PAC?',
#  'COREMSI': 'Client received core MSI service',
#  'FPCLIENTONLY': 'Clients that only received an FP method or an FP removal (i.e. did not receieve ',
#  'NMETH': 'Count number of services received',
#  'countSRH': 'Count number of SRH services receieved',
#  'FPCLIENT': 'Client received a family planning method',
#  'ADOPTER': 'Family Planning User Profile',
#  'SWITCH': 'Switched from a short-term method to a long-term method',
#  'FPNEVER': 'Is the client a first time user of FP?',
#  'FP2020': 'Method Information Index using 3 indicators',
#  'FP2020C': 'Comprehensive Method Information Index using othermeth_calc',
#  'FP2030': 'Method Information Index 2030 using all 4 indicators',
#  'PCCC': 'PCCC Score',
#  'RECCAT': 'Likelihood to recommend our services to a friend',
#  'RETCAT': 'Likelihood to return to this site or provider',
#  'SAT_PRIV': 'Strongly agreed or agreed that they had enough privacy during their visit today',
#  'SAT_REST': 'Strongly agreed or agreed that they were treated with respect by all MSI staff',
#  'SAT_WAIT': 'Strongly agreed or agreed that the time they had to wait was acceptable',
#  'SAT_CARE': 'Strongly agreed or agreed that the provider was easy to understand',
#  'SAT_ENOUGH': 'Strongly agreed or agreed that the provider gave enough information for the clie',
#  'SAT_SERIOUS': 'Strongly agreed or agreed that the provider took the clients preferences serious',
#  'SAT_RPRT': 'Strongly agreed or agreed the provider gave the opportunity to explain needs and',
#  'SAT_COMFORT': 'Strongly agreed or agreed that staff members made them comfortable during their ',
#  'SAT_PRIV_R': 'Strongly agreed that they trust the provider to keep their personal information ',
#  'SAT_REST_R': 'Strongly agreed that was treated with respect by all MSI staff',
#  'SAT_WAIT_R': 'Strongly agreed wait time was acceptable',
#  'SAT_CARE_R': 'Strongly agreed that the provider was easy to understand',
#  'SAT_ENOUGH_R': 'Strongly agreed that the provider gave me enough information to make the best de',
#  'SAT_SERIOUS_R': 'Strongly agreed that the provider took my preferences seriously',
#  'SAT_RPRT_R': 'Strongly agreed, the provider gave the opportunity to explain needs and ask ques',
#  'SAT_COMFORT_R': 'Strongly agreed that staff members made them comfortable during their visit',
#  'TR2D': 'Travel time in minutes',
#  'TR2DH2': 'How long did it take you to travel here today? (hours categorized)',
#  'POSIPC_A': 'Agree or strongly agree that within my community I hear positive stories about u',
#  'KSANCTION_A': 'Agree or strongly agree that women are stigmatised if our community knows that w',
#  'KMENSUPP_A': 'Agree or strongly agree that most men in my community are supportive of their pa',
#  'KCOMSUPP_A': 'Agree or strongly agree that within my community using modern contraception is a',
#  'KLEADSUP_A': 'Agree or strongly agree that within my community, local leaders encourage the us',
#  'age3grp_a': '15-24; 25-34; 35+',
#  'age4grp': '15-19; 20-24; 25-29; 30+',
#  'age3grp_b': '15-19; 20-24; 25+',
#  'YOUTH': 'Is the client between 15-24 years old?',
#  'ADOLESCENT': 'Is the client between 15-19 years old?',
#  'MAR_BINARY': 'Marital Status = Not Married Or In Union vs  Currently Married/Living with Partn',
#  'CHILD_GRP': 'Number of children, 3 categories',
#  'MARPAR_GRP': 'Marriage status and parity, 4 categories',
#  'NOEDUC': 'Education level: none / no formal',
#  'EDUC': 'Education level: some primary/completed primary/completed secondary',
#  'DISABILITY1': "Does the client indicate 'some' to 'cannot do at all' in any functional domain?",
#  'DISABILITY3': "Does the client indicate 'a lot' to 'cannot do at all' in any functional domain?",
#  'DISABILITY4': "Does the client indicate 'cannot do at all' in any functional domain?",
#  'filterSRH': 'Is this client an SRH client?',
#  'm_educ': 'MPI school years',
#  'm_satt': 'MPI school attendance',
#  'm_cm': 'MPI infant mortality',
#  'm_elct': 'MPI electricity',
#  'm_wtr': 'MPI water',
#  'm_sani': 'MPI sanitation',
#  'm_floor': 'MPI flooring',
#  'm_roof': 'MPI roof',
#  'm_wall': 'MPI wall',
#  'm_hsg': '',
#  'm_ckfl': 'MPI fuel',
#  'm_asst': '',
#  'mpiscore': '',
#  'hi_cm': '',
#  'hi_satt': '',
#  'hi_educ': '',
#  'hi_elct': '',
#  'hi_wtr': '',
#  'hi_sani': '',
#  'hi_hsg': '',
#  'hi_ckfl': '',
#  'hi_asst': '',
#  'himpiscore': '',
#  'lo_cm': '',
#  'lo_satt': '',
#  'lo_educ': '',
#  'lo_elct': '',
#  'lo_wtr': '',
#  'lo_sani': '',
#  'lo_hsg': '',
#  'lo_ckfl': '',
#  'lo_asst': '',
#  'lompiscore': '',
#  'mpi_poor': 'MPI poor (excl. nutrition indicator)',
#  'mpi_sevpoor': 'MPI severely poor (excl. nutrition indicator)',
#  'HICLIENT': 'Is the client a high impact client?',
#  'CEI_type': 'Type of CEI',
#  'fp_highest': 'FP Method ranked from longest acting (highest to lowest)',
#  'pillar1': ''}

# %% [markdown]
# ### 3. Data Overview and Summary Statistics

# %%
# Check basic information and first few rows of the stata
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 332 entries, 0 to 331
# Columns: 372 entries, starttime to pillar1
# dtypes: float64(20), int64(37), object(315)
# memory usage: 965.0+ KB

# %%
# Summary statistics for numerical columns
data.describe()
# Out:
#             TR2DH       TR2DM  PAINOP_IMPREM  PAINSCALE_DREM  PAINSCALE_AREM  \
# count  332.000000  332.000000       9.000000       18.000000       17.000000
# mean     0.319277   20.346386     222.666667        3.944444        3.352941
# std      0.729517   15.942984     332.500000        2.554632        2.737270
# min      0.000000    0.000000       1.000000        0.000000        0.000000
# 25%      0.000000   10.000000       1.000000        2.000000        1.000000
# 50%      0.000000   15.000000       1.000000        3.500000        3.000000
# 75%      0.000000   30.000000     666.000000        4.750000        4.000000
# max      6.000000   60.000000     666.000000       10.000000       10.000000
#
#            CMAUTO  PAINSCALE_DCM  PAINSCALE_ACM         AGE       CHILD  \
# count  330.000000      78.000000      78.000000  332.000000  332.000000
# mean     8.442424       3.743590       3.512821   30.268072    4.409639
# std      1.898172       2.645437       2.818048    7.148646    2.447200
# min      0.000000       0.000000       0.000000   15.000000    0.000000
# 25%      8.000000       2.000000       1.000000   25.000000    3.000000
# 50%      9.000000       3.000000       3.000000   30.000000    4.000000
# 75%     10.000000       5.000000       5.000000   35.000000    6.000000
# max     10.000000      10.000000      10.000000   55.000000   11.000000
#
#           IDEALFS           _id      _index          id          FP  \
# count  304.000000  3.320000e+02  332.000000  332.000000  332.000000
# mean     4.789474  4.228135e+08  167.355422  167.274096    0.912651
# std      2.187971  7.080085e+05   96.425042   96.423601    0.282773
# min      0.000000  4.213113e+08    1.000000    1.000000    0.000000
# 25%      4.000000  4.222490e+08   84.750000   83.750000    1.000000
# 50%      4.000000  4.229954e+08  167.500000  167.500000    1.000000
# 75%      6.000000  4.232956e+08  250.250000  250.250000    1.000000
# max     11.000000  4.241501e+08  334.000000  334.000000    1.000000
#
#         CHOICEtot  CHOICEtotAllMethods       NINFO      ENUMID       NMETH  \
# count  268.000000           268.000000  332.000000  332.000000  332.000000
# mean     3.059701             3.190299    1.030120   10.301205    0.578313
# std      2.096050             2.219504    0.919245    6.122584    0.494574
# min      0.000000             1.000000    0.000000    1.000000    0.000000
# 25%      1.000000             1.000000    0.000000    5.000000    0.000000
# 50%      3.000000             3.000000    1.000000    9.000000    1.000000
# 75%      5.000000             5.000000    1.000000   14.000000    1.000000
# max      7.000000             8.000000    4.000000   23.000000    1.000000
#
#          countSRH        TR2D      m_educ      m_satt        m_cm      m_elct  \
# count  332.000000  332.000000  330.000000  330.000000  332.000000  331.000000
# mean     1.683735   39.503012    0.572727    0.439394    0.078313    0.338369
# std      0.606591   50.408932    0.495434    0.497067    0.269069    0.473871
# min      0.000000    1.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   10.000000    0.000000    0.000000    0.000000    0.000000
# 50%      2.000000   20.000000    1.000000    0.000000    0.000000    0.000000
# 75%      2.000000   35.000000    1.000000    1.000000    0.000000    1.000000
# max      4.000000  420.000000    1.000000    1.000000    1.000000    1.000000
#
#             m_wtr      m_sani     m_floor      m_roof     m_wall       m_hsg  \
# count  311.000000  318.000000  332.000000  332.000000  332.00000  313.000000
# mean     0.356913    0.676101    7.521084    5.698795    5.73494    0.437700
# std      0.479861    0.468700   25.578790   22.377284   22.36883    0.496898
# min      0.000000    0.000000    0.000000    0.000000    0.00000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.00000    0.000000
# 50%      0.000000    1.000000    0.000000    0.000000    0.00000    0.000000
# 75%      1.000000    1.000000    1.000000    1.000000    1.00000    1.000000
# max      1.000000    1.000000   99.000000   99.000000   99.00000    1.000000
#
#            m_ckfl      m_asst    mpiscore       hi_cm     hi_satt     hi_educ  \
# count  316.000000  332.000000  306.000000  332.000000  332.000000  332.000000
# mean     0.316456    0.280120   32.824981    0.078313    0.442771    0.575301
# std      0.465831    0.449736   20.228001    0.269069    0.497464    0.495043
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000   16.666666    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000   33.333332    0.000000    0.000000    1.000000
# 75%      1.000000    1.000000   44.444443    0.000000    1.000000    1.000000
# max      1.000000    1.000000   88.888885    1.000000    1.000000    1.000000
#
#           hi_elct      hi_wtr     hi_sani      hi_hsg     hi_ckfl     hi_asst  \
# count  332.000000  332.000000  332.000000  332.000000  332.000000  332.000000
# mean     0.340361    0.397590    0.689759    0.469880    0.349398    0.280120
# std      0.474546    0.490139    0.463290    0.499845    0.477499    0.449736
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    1.000000    0.000000    0.000000    0.000000
# 75%      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#        himpiscore       lo_cm     lo_satt     lo_educ     lo_elct      lo_wtr  \
# count  332.000000  332.000000  332.000000  332.000000  332.000000  332.000000
# mean    33.617804    0.078313    0.436747    0.569277    0.337349    0.334337
# std     19.972869    0.269069    0.496732    0.495925    0.473519    0.472470
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%     16.666666    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%     33.333332    0.000000    0.000000    1.000000    0.000000    0.000000
# 75%     44.444443    0.000000    1.000000    1.000000    1.000000    1.000000
# max     88.888885    1.000000    1.000000    1.000000    1.000000    1.000000
#
#           lo_sani      lo_hsg     lo_ckfl     lo_asst  lompiscore  \
# count  332.000000  332.000000  332.000000  332.000000  332.000000
# mean     0.647590    0.412651    0.301205    0.280120   32.228915
# std      0.478442    0.493054    0.459474    0.449736   20.257378
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000   16.666666
# 50%      1.000000    0.000000    0.000000    0.000000   33.333332
# 75%      1.000000    1.000000    1.000000    1.000000   44.444443
# max      1.000000    1.000000    1.000000    1.000000   88.888885
#
#        mpi_sevpoor     pillar1
# count   332.000000  332.000000
# mean      0.225904    0.325301
# std       0.418807    0.469194
# min       0.000000    0.000000
# 25%       0.000000    0.000000
# 50%       0.000000    0.000000
# 75%       0.000000    1.000000
# max       1.000000    1.000000

# %%
# Data Collection Dates
overall_start_date = data['starttime'].min()  # Earliest start date
overall_end_date = data['endtime'].max()  # Latest end date

print(f"Data Collection Start Date: {overall_start_date}")
print(f"Data Collection End Date: {overall_end_date}")
# Out:
# Data Collection Start Date: 17-Dec-24
# Data Collection End Date: 26-Dec-24

# %% [markdown]
# ## Module 1: Interview and Site Information
#
# ### Variables
# - 'DATE': "Enter today's date",
# - 'FACTYPE': 'Type of facility or site',
# - 'NAME_C': 'Enter the name of the Centre',
# - 'NAME_OR': 'Enter the name of the Outreach site',
# - 'NAME_SF': 'Enter the name of the Social Franchise',
# - 'NAME_MSL': 'Enter the name of the MS Lady/ site',
# - 'NAME_PSS': 'Enter the name of the PSS site',
# - 'NAME_OTH': 'Enter the name of the site',
# - 'REGION': 'Enter facility/site region',
# - 'LOCATION': 'Enter type of location',
#
# ### Analysis Questions
# 1. How is the distribution of facility types across regions?
# 2. What is the most common location type for different facility types?

# %% [markdown]
# #### 1. How is the distribution of facility types across service channel?

# %%
# Distribution of surveys accorss each site
site_distribution = data.groupby('FACTYPE').size().reset_index(name="Total Surveys in Each Site")

site_distribution.sort_values(by='Total Surveys in Each Site', inplace=True, ascending=False)

site_distribution
# Out:
#       FACTYPE  Total Surveys in Each Site
# 1  MSI centre                         114
# 2    Outreach                         110
# 0     MS Lady                         108

# %%
plot_vertical_bar_chart(site_distribution['FACTYPE'], site_distribution['Total Surveys in Each Site'], colors)

# %%
# How is the distribution of facility types across regions?

facility_types = data.groupby(['REGION', 'FACTYPE']).size().reset_index(name='Count')
facility_types.sort_values(by='REGION', inplace=True)

facility_types
# Out:
#     REGION     FACTYPE  Count
# 0  Central  MSI centre     29
# 1     East  MSI centre     10
# 2    North     MS Lady     64
# 3    North  MSI centre     32
# 4    North    Outreach     69
# 5    South     MS Lady     23
# 6    South  MSI centre     19
# 7     West     MS Lady     21
# 8     West  MSI centre     24
# 9     West    Outreach     41

# %%
# Add percentage/proportion column
region_totals = facility_types.groupby('REGION')['Count'].transform('sum')
facility_types['Percentage'] = (facility_types['Count'] / region_totals) * 100

# %%
facility_types
# Out:
#     REGION     FACTYPE  Count  Percentage
# 0  Central  MSI centre     29  100.000000
# 1     East  MSI centre     10  100.000000
# 2    North     MS Lady     64   38.787879
# 3    North  MSI centre     32   19.393939
# 4    North    Outreach     69   41.818182
# 5    South     MS Lady     23   54.761905
# 6    South  MSI centre     19   45.238095
# 7     West     MS Lady     21   24.418605
# 8     West  MSI centre     24   27.906977
# 9     West    Outreach     41   47.674419

# %%
plot_distribution(facility_types, index='REGION', cols='FACTYPE', values='Count', colors=colors)

# %% [markdown]
# #### 2. What is the most common location type for different facility type channels?

# %%
# Step: Cross-tabulation or contingency table between FACTYPE and LOCATION

common_location_type = pd.crosstab(data['FACTYPE'], data['LOCATION'])

common_location_type
# Out:
# LOCATION    Peri-urban  Rural  Urban
# FACTYPE
# MS Lady             10     38     60
# MSI centre           5     10     99
# Outreach            62     25     23

# %%
#heatmap for visualization of above table
sns.heatmap(common_location_type, annot=True, cmap=colors, fmt='d', cbar=False)
#plt.title("Facilty Type in Different Locations")
plt.show()

# %% [markdown]
# ## Module 2: Demographic Module
# ### A. Demographic Profile
# 1. What is the age range and median age of the respondents?
# 2. What is the education distribution attained by the respondents?
# 3. What distribution of respondents are married, single, divorced, or widowed?
# 4. How many respondents have children, and what is the average number of children per respondent?

# %% [markdown]
# #### 1. What is the age range and median age of the respondents?

# %%
min_age = data['AGE'].min()
max_age = data['AGE'].max()
average_age = data['AGE'].mean()
median_age = data['AGE'].median()

print(f"The age range of respondents is: {min_age} to {max_age}")

print(f"The average age of respondents is {np.round(average_age, 2)} and median value is {round(median_age, 2)}")
# Out:
# The age range of respondents is: 15 to 55
# The average age of respondents is 30.27 and median value is 30.0

# %% [markdown]
# #### 2. What is the education distribution attained by the respondents?

# %%
# Function to calculate percentage
def calculate_percentage(df, count_column):
    total = df[count_column].sum()
    df['Percentage'] = (df[count_column] / total) * 100
    return df

# Overall education level of respondents
education_level = data.groupby('EDU').size().reset_index(name='Count')

# Call the function to calculate percentage
education_level = calculate_percentage(education_level, 'Count')

# Sort the values by 'Count' in descending order
education_level.sort_values(by='Count', inplace=True, ascending=True)

education_level
# Out:
#                                             EDU  Count  Percentage
# 4       Some secondary, vocational or technical      9    2.710843
# 5                       Some tertiary or higher     16    4.819277
# 1  Completed secondary, vocational or technical     17    5.120482
# 0                             Completed primary     43   12.951807
# 3                                  Some primary     54   16.265060
# 2                             None / non-formal    193   58.132530

# %%
# Now, call the function with your data
plot_bar_chart_with_percentage(education_level, 'EDU', 'Count', colors=colors)

# %%
# channel-based education level of each respodent
data.groupby(['FACTYPE', 'EDU']).size().reset_index()
# Out:
#        FACTYPE                                           EDU   0
# 0      MS Lady                             Completed primary  25
# 1      MS Lady  Completed secondary, vocational or technical  12
# 2      MS Lady                             None / non-formal  54
# 3      MS Lady                                  Some primary  13
# 4      MS Lady       Some secondary, vocational or technical   3
# 5      MS Lady                       Some tertiary or higher   1
# 6   MSI centre                             Completed primary  17
# 7   MSI centre  Completed secondary, vocational or technical   5
# 8   MSI centre                             None / non-formal  59
# 9   MSI centre                                  Some primary  12
# 10  MSI centre       Some secondary, vocational or technical   6
# 11  MSI centre                       Some tertiary or higher  15
# 12    Outreach                             Completed primary   1
# 13    Outreach                             None / non-formal  80
# 14    Outreach                                  Some primary  29

# %% [markdown]
# #### 3. What distribution of respondents are married, divorced, or widowed?

# %%
marital_status = data.groupby('MAR').size().reset_index(name="Count")

marital_status
# Out:
#        MAR  Count
# 0  Married    332

# %% [markdown]
# #### 4. How many respondents have children, and what is the average number of children per respondent?

# %%
data.groupby('CHILD').size().reset_index(name='Total Respondents')
# Out:
#     CHILD  Total Respondents
# 0       0                  5
# 1       1                 31
# 2       2                 41
# 3       3                 60
# 4       4                 50
# 5       5                 47
# 6       6                 34
# 7       7                 17
# 8       8                 24
# 9       9                 12
# 10     10                  8
# 11     11                  3

# %%
print(f"Five respondents reported that they have {data['CHILD'].min()} number of children.")
print(f"On Average the respondents reported {round(data['CHILD'].mean(), 0)} number of children.")
# Out:
# Five respondents reported that they have 0 number of children.
# On Average the respondents reported 4.0 number of children.

# %% [markdown]
# ### B. Employment and Displacement
# 1. What are the most common occupations of the respondents?
# 2. What percentage of respondents have experienced displacement?
# 3. What are the primary reasons for displacement?

# %% [markdown]
# #### 1. What are the most common occupations of the respondents?

# %%
occupation = data.groupby('JOB').size().reset_index(name='Total Respondents')

occupation.sort_values(by='Total Respondents', inplace=True)

occupation
# Out:
#                                      JOB  Total Respondents
# 4                         Skilled manual                  1
# 7                Unskilled manual - paid                  1
# 0                     Agriculture - paid                  2
# 1                   Agriculture - unpaid                  3
# 3  Professional / technical / managerial                 16
# 5           Unemployed, looking for work                 17
# 6  Unemployed, not looking for paid work                 70
# 2                              Homemaker                222

# %%
# Visualize job distribution
plot_bar_chart_with_percentage(occupation, 'JOB', 'Total Respondents', colors=colors)

# %% [markdown]
# #### 2. What percentage of respondents have experienced displacement?

# %%
displaced = data.groupby('DISPLACED').size().reset_index(name = 'Count')

displaced['Percentage'] = (displaced['Count'] / len(data)) * 100

displaced.sort_values(by='Count', inplace=True, ascending=False)

displaced
# Out:
#   DISPLACED  Count  Percentage
# 0        No    290   87.349398
# 1       Yes     42   12.650602

# %%
# Count the number of respondents who are displaced
displaced_count = data[data['DISPLACED'] == 'Yes'].shape[0]

# Calculate the displaced percentage
displaced_percentage = (displaced_count / len(data)) * 100

# Printing the result
print(f"{displaced_percentage:.2f}% responded that they have been displaced from their original hometown.")
# Out:
# 12.65% responded that they have been displaced from their original hometown.

# %%
plot_vertical_bar_chart(displaced['DISPLACED'], displaced['Count'], colors)

# %% [markdown]
# #### 4. What are the primary reasons for displacement?

# %%
# The primary displacement reason

displacedment_reasons = data[data['DISPLACED'] == 'Yes'].groupby('WHY_DISPB').size().reset_index(name='Number of Respondents Displaced')

displacedment_reasons.sort_values(by='Number of Respondents Displaced', inplace=True, ascending=True)

displacedment_reasons
# Out:
#                                            WHY_DISPB  \
# 2                                          Education
# 4                                              Other
# 0  Displacement due to natural disaster/climate c...
# 3  Forced displacement due to armed conflict and ...
# 1                                   Economic reasons
#
#    Number of Respondents Displaced
# 2                                1
# 4                                1
# 0                                6
# 3                               10
# 1                               21

# %%
plot_bar_chart_with_percentage(displacedment_reasons, 'WHY_DISPB', 'Number of Respondents Displaced', colors=colors)

# %% [markdown]
# ### C. Disabilities and Accessibility
# 1. What percentage of respondents report difficulty in seeing, hearing, walking, or climbing steps?
# 2. A region-wise analysis to identify the portion of beneficieries with disabilities.
#
# #### Variables:
# - DIS1: Do you have difficulty seeing?
# - DIS2: Do you have difficulty hearing?
# - DIS3: Do you have difficulty sitting, standing, walking or climbing steps? -
# - DIS4: Do you have difficulty remembering or concentrating?
# - DIS5: Do you have difficulty with self-care?
# - DIS6: Using your usual language, do you have difficulty communicating?
#
# #### Formula to Calculate Disability Prevalence:
#
# - Disability=Any response in {Seeing, Hearing, Walking, Remembering, Self-care, Communicating} ≥ 3
#
# - Responses should be coded as:
# 1 = No difficulty
# 2 = Some difficulty
# 3 = A lot of difficulty
# 4 = Cannot do it at all
#
# - Prevalence Rate = (Number of Respondents with a Disability / Total Number of Respondents) * 100

# %%
# original responses
data['DIS1'].unique()
# Out:
# array(['No - no difficulty', 'Yes – some difficulty',
#        'Yes – a lot of difficulty'], dtype=object)

# %%
# Columns related to disability
disability_columns = ["DIS1", "DIS2", "DIS3", "DIS4", "DIS5", "DIS6"]

# %%
# Mapping dictionary
response_map = {
    "No - no difficulty": 1,
    "Yes – some difficulty": 2,
    "Yes – a lot of difficulty": 3,
    "Cannot do it at all": 4,
}

# %%
data[disability_columns] = data[disability_columns].applymap(response_map.get)

# %%
# Define a function to identify disability
def has_disability(row):
  return any(row >= 3)

# %%
# Apply the function across rows
data['Disability'] = data[disability_columns].apply(lambda row: has_disability(row), axis=1)

# %%
data['Disability'].head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Disability, dtype: bool

# %%
prevalence_rate = (data['Disability'].sum() / len(data)) * 100

# %%
# Output results
print(f"Disability Prevalence Rate: {prevalence_rate:.2f}%")
# Out:
# Disability Prevalence Rate: 7.23%

# %%
# Count the number of respondents with and without a disability
disability_counts = data['Disability'].value_counts().reset_index(name='Count')
disability_counts
# Out:
#    Disability  Count
# 0       False    308
# 1        True     24

# %%
plot_vertical_bar_chart(disability_counts['Disability'], disability_counts['Count'], colors)

# %%
region_wise_disability = data.groupby(['FACTYPE', 'Disability']).size().reset_index(name='Total')
region_wise_disability
# Out:
#       FACTYPE  Disability  Total
# 0     MS Lady       False     95
# 1     MS Lady        True     13
# 2  MSI centre       False    108
# 3  MSI centre        True      6
# 4    Outreach       False    105
# 5    Outreach        True      5

# %%
plot_distribution(region_wise_disability, index='FACTYPE', cols='Disability', values='Total', colors=colors)

# %% [markdown]
# ### C. Household and Living Conditions
# 1. What percentage of households have completed six years or more of schooling?
# 2. Are children in the household aged 5–13 currently attending school?
# 3. What is the proportion of households that have experienced the death of a member under 18 in the past five years?
# 4. What are the primary materials used for floors, walls, and roofs in households?
# 5. Is the toilet or latrine shared with other households?
# 6. What are the most common types of toilet facilities in the surveyed households?
# 7. How far do respondents travel to access drinking water?
# 8. What is the source of drinking water in your household?
# 9. What percentage of households have electricity?

# %%
# Mapping variable names to full text
question_mapping = {
    'MPI_YS': 'What percentage of households have completed six years or more of schooling?',
    'MPI_SCA': 'Are children in the household aged 5–13 currently attending school?',
    'MPI_CM': 'What is the proportion of households that have experienced the death of a member under 18 in the past five years?',
    'MPI_FLR': 'What are the primary materials used for floors, walls, and roofs in households?',
    'MPI_TOSHR': 'Is the toilet or latrine shared with other households?',
    'MPI_TO': 'What are the most common types of toilet facilities in the surveyed households?',
    'MPI_WATDIS': 'How long does it take to get to your drinking water source, get water and come back?',
    'MPI_WAT': 'What is the source of drinking water in your household?',
    'MPI_ELEC': 'Do you have electricity at home?',
}

variable_list = list(question_mapping.keys())  # Replace with your list of questions

# Generate the summary table
summary_table = summary_percentage_table(
    data,
    variable_list,
    question_mapping,
    channels_column='channels',
    regions=channels
)

# Display the result
summary_table
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[80], line 17
#      14 variable_list = list(question_mapping.keys())  # Replace with your list of questions
#      16 # Generate the summary table
# ---> 17 summary_table = summary_percentage_table(
#      18     data,
#      19     variable_list,
#      20     question_mapping,
#      21     channels_column='channels',
#      22     regions=channels
#      23 )
#      25 # Display the result
#      26 summary_table
#
# TypeError: summary_percentage_table() got an unexpected keyword argument 'channels_column'

# %%
from google.colab import files

# Save the summary table to an Excel file
file_path = 'Household and Living Conditions.xlsx'  # Save to the current directory in Colab
summary_table.to_excel(file_path, index=False, sheet_name="Summary Table")

# Automatically download the file
files.download(file_path)

# %% [markdown]
# ### D. Assets and Resources
#
# 1. What type of cooking fuel is most commonly used by respondents?
# 2. What percentage of households own cars, trucks, or other significant assets?
# 3. How many households own multiple assets, such as telephones, radios, etc.?

# %%
# Mapping variable names to full text
question_mapping = {
    'MPI_CF': 'What type of fuel does your household mainly use for cooking?',
    'MPI_TRUCK': 'Does your household own a car or truck?',
    'MPI_ASSETS': 'Does your household own more than one of the following assets?  Telephone, radio',
}

variable_list = list(question_mapping.keys())  # Replace with your list of questions
regions = ['Central', 'East', 'West', 'North', 'South']  # Specify regions

# Generate the summary table
assets_and_resources = summary_percentage_table(
    data,
    variable_list,
    question_mapping,
    regions_column='REGION',
    regions=regions
)

# Display the result
assets_and_resources
# Out:
#                                             Question  \
# 0  What type of fuel does your household mainly u...
# 1  What type of fuel does your household mainly u...
# 2  What type of fuel does your household mainly u...
# 3  What type of fuel does your household mainly u...
# 4            Does your household own a car or truck?
# 5            Does your household own a car or truck?
# 6  Does your household own more than one of the f...
# 7  Does your household own more than one of the f...
# 8  Does your household own more than one of the f...
#
#                                              Answers Central    East    West  \
# 0  Electricity, liquid propane gas (LPG), natural...  89.66%  70.00%  74.42%
# 1  Straw/shrubs/grass, agricultural crop, animal ...  10.34%  30.00%  24.42%
# 2                                              Other   0.00%   0.00%   1.16%
# 3                                            Refused   0.00%   0.00%   0.00%
# 4                                                 No  72.41%  90.00%  86.05%
# 5                                                Yes  27.59%  10.00%  13.95%
# 6                                                Yes  68.97%  70.00%  70.93%
# 7                                                 No   3.45%  20.00%  15.12%
# 8                                            Refused   0.00%   0.00%   0.00%
#
#     North   South   Total
# 0  59.04%  51.16%  68.85%
# 1  40.96%  11.63%  23.47%
# 2   0.00%  34.88%   7.21%
# 3   0.00%   2.33%   0.47%
# 4  88.55%  93.02%  86.01%
# 5  11.45%   6.98%  13.99%
# 6  50.60%  55.81%  63.26%
# 7  37.35%  32.56%  21.69%
# 8   0.60%   4.65%   1.05%

# %%
# Save the summary table to an Excel file
file_path = 'Assets and Resources.xlsx'  # Save to the current directory in Colab
assets_and_resources.to_excel(file_path, index=False, sheet_name="Summary Table")

# Automatically download the file
files.download(file_path)

# %% [markdown]
# # Module 2: Service Access and Uptake

# %% [markdown]
# ### 1. Service Access

# %%
service_access_variables = {
    'TR2DH': 'How long did it take you to travel here today? Hours',
    'TR2DM': 'How long did it take you to travel here today? Minutes',
    'HOURS': 'Was it clear to you what hours the facility was open/when you could come in to receive services?',
    'FEED': 'Were you informed on how to give feedback or complain about your experience today?'
}

variable_list = list(service_access_variables.keys())  # Replace with your list of questions
regions = ['Central', 'East', 'West', 'North', 'South']  # Specify regions

# Generate the summary table
service_access_table = summary_percentage_table(
    data,
    variable_list,
    service_access_variables,
    regions_column='REGION',
    regions=regions
)

# Display the result
service_access_table
# Out:
#                                              Question     Answers  Central  \
# 0   How long did it take you to travel here today?...           0   55.17%
# 1   How long did it take you to travel here today?...           2   13.79%
# 2   How long did it take you to travel here today?...           1   31.03%
# 3   How long did it take you to travel here today?...           6    0.00%
# 4   How long did it take you to travel here today?...           3    0.00%
# 5   How long did it take you to travel here today?...          20   17.24%
# 6   How long did it take you to travel here today?...          10   17.24%
# 7   How long did it take you to travel here today?...           0   20.69%
# 8   How long did it take you to travel here today?...          15   13.79%
# 9   How long did it take you to travel here today?...          30   27.59%
# 10  How long did it take you to travel here today?...           5    0.00%
# 11  How long did it take you to travel here today?...          60    0.00%
# 12  How long did it take you to travel here today?...          50    0.00%
# 13  How long did it take you to travel here today?...          16    0.00%
# 14  How long did it take you to travel here today?...          40    0.00%
# 15  How long did it take you to travel here today?...           8    0.00%
# 16  How long did it take you to travel here today?...           2    0.00%
# 17  How long did it take you to travel here today?...          45    0.00%
# 18  How long did it take you to travel here today?...          25    0.00%
# 19  How long did it take you to travel here today?...           6    0.00%
# 20  How long did it take you to travel here today?...           1    0.00%
# 21  How long did it take you to travel here today?...          35    3.45%
# 22  How long did it take you to travel here today?...          39    0.00%
# 23  Was it clear to you what hours the facility wa...         Yes  100.00%
# 24  Was it clear to you what hours the facility wa...          No    0.00%
# 25  Was it clear to you what hours the facility wa...  Don't know    0.00%
# 26  Was it clear to you what hours the facility wa...     Refused    0.00%
# 27  Were you informed on how to give feedback or c...         Yes   96.55%
# 28  Were you informed on how to give feedback or c...          No    3.45%
# 29  Were you informed on how to give feedback or c...  Don't know    0.00%
#
#        East    West   North   South   Total
# 0    70.00%  97.67%  83.73%  39.53%  69.22%
# 1     0.00%   1.16%   6.63%   0.00%   4.32%
# 2    30.00%   1.16%   5.42%  58.14%  25.15%
# 3     0.00%   0.00%   0.00%   2.33%   0.47%
# 4     0.00%   0.00%   4.22%   0.00%   0.84%
# 5    10.00%  13.95%   9.64%   0.00%  10.17%
# 6    30.00%  13.95%  37.95%   0.00%  19.83%
# 7     0.00%   0.00%   1.81%   0.00%   4.50%
# 8    10.00%  12.79%  19.28%   0.00%  11.17%
# 9    20.00%  18.60%  13.25%  30.23%  21.94%
# 10   10.00%  23.26%  12.05%   0.00%   9.06%
# 11    0.00%   0.00%   0.60%  60.47%  12.21%
# 12    0.00%   1.16%   1.81%   9.30%   2.45%
# 13    0.00%   0.00%   0.60%   0.00%   0.12%
# 14   10.00%   1.16%   0.60%   0.00%   2.35%
# 15    0.00%   1.16%   0.00%   0.00%   0.23%
# 16    0.00%   5.81%   0.00%   0.00%   1.16%
# 17    0.00%   0.00%   0.60%   0.00%   0.12%
# 18   10.00%   2.33%   1.20%   0.00%   2.71%
# 19    0.00%   1.16%   0.00%   0.00%   0.23%
# 20    0.00%   1.16%   0.00%   0.00%   0.23%
# 21    0.00%   2.33%   0.60%   0.00%   1.28%
# 22    0.00%   1.16%   0.00%   0.00%   0.23%
# 23  100.00%  54.65%  61.45%  62.79%  75.78%
# 24    0.00%  45.35%  13.86%  16.28%  15.10%
# 25    0.00%   0.00%  23.49%  20.93%   8.88%
# 26    0.00%   0.00%   1.20%   0.00%   0.24%
# 27  100.00%  66.28%  86.75%  62.79%  82.47%
# 28    0.00%  30.23%  11.45%  30.23%  15.07%
# 29    0.00%   3.49%   1.81%   6.98%   2.45%

# %%
# Save the summary table to an Excel file
file_path = 'service_access_table.xlsx'  # Save to the current directory in Colab
service_access_table.to_excel(file_path, index=False, sheet_name="Summary Table")

# Automatically download the file
files.download(file_path)

# %% [markdown]
# ### 2. Service Update

# %%
service_update_variables = {
    'GEN_SAT': 'Overall, how satisfied are you with your experience with us today?',
    'REC': 'Based on your experience today, how likely are you to recommend our services?',
    'RET': 'Based on your experience today, if you needed a similar service in the future, how likely are you to return?',
    'PRIV': 'I had enough privacy during my visit today.',
    'REST': 'I was treated with respect by all staff during my visit today.',
    'WAIT': 'The time I waited to see a provider today was acceptable.',
    'CARE': 'The provider was easy to understand.',
    'ENOUGH': 'The provider gave me enough information to make the best decisions about my method.',
    'SERIOUS': 'The provider took my preferences seriously.',
    'RPRT': 'The provider gave me the opportunity to explain my needs and ask questions.',
    'COMFORT': 'All staff members made me comfortable during my visit today.',
    'IMPEDU': 'Do you feel that the service you received today will have a positive Impact on education',
    'IMPWRK': 'Do you feel that the service you received today will have a positive Impact on work',
    'IMPFAM': 'Do you feel that the service you received today will have a positive Impact on family',
    'IMPHLTH': 'Do you feel that the service you received today will have a positive Impact on health',
    'IMPOTH': 'Do you feel that the service you received today will have a positive Impact on other aspects of life',
    'IMPNONE': 'No perceived impact',
    'IMPDK': 'Don’t know if there was an impact',
    'IMPREF': 'Do you feel that the service(s) you received today will have a positive Impact on preferences'
}

variable_list = list(service_update_variables.keys())  # Replace with your list of questions
regions = ['Central', 'East', 'West', 'North', 'South']  # Specify regions

# Generate the summary table
service_update_table = summary_percentage_table(
    data,
    variable_list,
    service_update_variables,
    regions_column='REGION',
    regions=regions
)

# Display the result
service_update_table
# Out:
#                                              Question                Answers  \
# 0   Overall, how satisfied are you with your exper...         Very satisfied
# 1   Overall, how satisfied are you with your exper...     Somewhat satisfied
# 2   Overall, how satisfied are you with your exper...  Somewhat dissatisfied
# 3   Overall, how satisfied are you with your exper...                Refused
# 4   Based on your experience today, how likely are...  Promoter -Very Likely
# ..                                                ...                    ...
# 65                                No perceived impact                    Yes
# 66                  Don’t know if there was an impact                     No
# 67                  Don’t know if there was an impact                    Yes
# 68  Do you feel that the service(s) you received t...                     No
# 69  Do you feel that the service(s) you received t...                    Yes
#
#     Central     East     West   North   South   Total
# 0   100.00%   90.00%   83.72%  92.17%  97.67%  92.71%
# 1     0.00%    0.00%   15.12%   6.63%   0.00%   4.35%
# 2     0.00%   10.00%    1.16%   1.20%   0.00%   2.47%
# 3     0.00%    0.00%    0.00%   0.00%   2.33%   0.47%
# 4    86.21%  100.00%   89.53%  87.35%  39.53%  80.53%
# ..      ...      ...      ...     ...     ...     ...
# 65    0.00%   10.00%    0.00%   1.81%   9.30%   4.22%
# 66  100.00%  100.00%  100.00%  98.80%  81.40%  96.04%
# 67    0.00%    0.00%    0.00%   1.20%  18.60%   3.96%
# 68  100.00%  100.00%  100.00%  99.40%  93.02%  98.48%
# 69    0.00%    0.00%    0.00%   0.60%   6.98%   1.52%
#
# [70 rows x 8 columns]

# %%
# Save the summary table to an Excel file
file_path = 'service_update_table.xlsx'  # Save to the current directory in Colab
service_update_table.to_excel(file_path, index=False, sheet_name="Summary Table")

# Automatically download the file
files.download(file_path)

# %% [markdown]
# ##  Module 3: Family Planning History

# %%
# Calculate percentage and count of "Yes" and "No" for FPEVER
family_planning_variables = {
    "FPEVER": "Have you ever used a method of contraception before today?",
    "FPWANT": "Do you currently want to be using any method of contraception?",
    "FPCURR": "Have you or your partner used any method of contraception during the past 3 months?",
    "CMETH": "What was the main method of contraception that you were using in the past 3 months?",
    "Prev_FPmethod": "(Calculation or record of the previous FP method).",
    "FPWHERE": "Prior to your visit today, where did you get the method that you were using most recently?",
    "CMADD": "Have you or your partner/s used any additional methods of contraception in the past 3 months?",
    "CMCURWNT": "Prior to your visit today, did you want to be using the method?",
    "CMACCESS": "Have there been times you wanted to use this method but could not access it?"
}

variable_list = list(family_planning_variables.keys())
regions = ['Central', 'East', 'West', 'North', 'South']  # Specify regions

# Generate the summary table
family_planning_table = summary_percentage_table(
    data,
    variable_list,
    family_planning_variables,
    regions_column='REGION',
    regions=regions
)

# Display the result
family_planning_table
# Out:
#                                              Question  \
# 0   Have you ever used a method of contraception b...
# 1   Have you ever used a method of contraception b...
# 2   Have you ever used a method of contraception b...
# 3   Do you currently want to be using any method o...
# 4   Do you currently want to be using any method o...
# 5   Do you currently want to be using any method o...
# 6   Do you currently want to be using any method o...
# 7   Do you currently want to be using any method o...
# 8   Have you or your partner used any method of co...
# 9   Have you or your partner used any method of co...
# 10  Have you or your partner used any method of co...
# 11  Have you or your partner used any method of co...
# 12  What was the main method of contraception that...
# 13  What was the main method of contraception that...
# 14  What was the main method of contraception that...
# 15  What was the main method of contraception that...
# 16  What was the main method of contraception that...
# 17  What was the main method of contraception that...
# 18  What was the main method of contraception that...
# 19  What was the main method of contraception that...
# 20  What was the main method of contraception that...
# 21  (Calculation or record of the previous FP meth...
# 22  (Calculation or record of the previous FP meth...
# 23  (Calculation or record of the previous FP meth...
# 24  (Calculation or record of the previous FP meth...
# 25  (Calculation or record of the previous FP meth...
# 26  (Calculation or record of the previous FP meth...
# 27  Prior to your visit today, where did you get t...
# 28  Prior to your visit today, where did you get t...
# 29  Prior to your visit today, where did you get t...
# 30  Prior to your visit today, where did you get t...
# 31  Prior to your visit today, where did you get t...
# 32  Prior to your visit today, where did you get t...
# 33  Have you or your partner/s used any additional...
# 34  Have you or your partner/s used any additional...
# 35  Have you or your partner/s used any additional...
# 36  Prior to your visit today, did you want to be ...
# 37  Prior to your visit today, did you want to be ...
# 38  Prior to your visit today, did you want to be ...
# 39  Prior to your visit today, did you want to be ...
# 40  Have there been times you wanted to use this m...
# 41  Have there been times you wanted to use this m...
#
#                                               Answers Central    East    West  \
# 0                                                 Yes  96.55%  80.00%  93.02%
# 1                                                  No   3.45%  20.00%   6.98%
# 2                                             Refused   0.00%   0.00%   0.00%
# 3                                                 Yes  96.55%  80.00%  90.70%
# 4                                                  No   3.45%  10.00%   9.30%
# 5                                          Don't know   0.00%   0.00%   0.00%
# 6                                           Sometimes   0.00%  10.00%   0.00%
# 7                                             Refused   0.00%   0.00%   0.00%
# 8                                                 Yes  93.10%  80.00%  83.72%
# 9                                                  No   3.45%   0.00%   9.30%
# 10                                          Sometimes   0.00%   0.00%   0.00%
# 11                                         Don't know   0.00%   0.00%   0.00%
# 12                                       Male condoms  44.83%  50.00%  22.09%
# 13                                     Female condoms   3.45%   0.00%   0.00%
# 14                                           Implants  13.79%   0.00%   2.33%
# 15                                Contraceptive pills  13.79%  10.00%  38.37%
# 16                                           IUD/ IUS   6.90%  10.00%   9.30%
# 17                                        Injectables  10.34%   0.00%  11.63%
# 18                                            Refused   0.00%  10.00%   0.00%
# 19      Breast-feeding: lactational amenorrhea method   0.00%   0.00%   0.00%
# 20  Traditional methods: Fertility awareness, cale...   0.00%   0.00%   0.00%
# 21                                       Male Condoms  44.83%  50.00%  22.09%
# 22                                     Female condoms   3.45%   0.00%   0.00%
# 23                                           Implants  13.79%   0.00%   2.33%
# 24                                Contraceptive pills  13.79%  10.00%  38.37%
# 25                                            IUD/IUS   6.90%  10.00%   9.30%
# 26                                        Injectibles  10.34%   0.00%  11.63%
# 27                         MSI – this facility / site  89.66%  40.00%  54.65%
# 28                                           Pharmacy   3.45%  20.00%  10.47%
# 29                      MSI – another facility / site   0.00%  10.00%   5.81%
# 30                                   Private provider   0.00%   0.00%   2.33%
# 31                                Government provider   0.00%   0.00%  10.47%
# 32                                         Don't know   0.00%   0.00%   0.00%
# 33                                                Yes  93.10%  70.00%  63.95%
# 34                                                 No   0.00%  10.00%  18.60%
# 35                                          Sometimes   0.00%   0.00%   1.16%
# 36                                                 No  68.97%   0.00%  23.26%
# 37                                                Yes  24.14%  70.00%  25.58%
# 38                                         Don't know   0.00%   0.00%  17.44%
# 39                                          Sometimes   0.00%   0.00%  17.44%
# 40                                                Yes   0.00%   0.00%   0.00%
# 41                                                 No   0.00%   0.00%   0.00%
#
#      North   South   Total
# 0   87.35%  83.72%  88.13%
# 1   12.65%  13.95%  11.41%
# 2    0.00%   2.33%   0.47%
# 3   81.33%  86.05%  86.92%
# 4   14.46%  13.95%  10.23%
# 5    3.01%   0.00%   0.60%
# 6    0.60%   0.00%   2.12%
# 7    0.60%   0.00%   0.12%
# 8   68.67%  55.81%  76.26%
# 9   13.86%  23.26%   9.97%
# 10   4.82%   2.33%   1.43%
# 11   0.00%   2.33%   0.47%
# 12  36.14%   2.33%  31.08%
# 13   0.00%  16.28%   3.95%
# 14   6.02%   0.00%   4.43%
# 15  13.86%  13.95%  17.99%
# 16   2.41%  11.63%   8.05%
# 17  13.25%  13.95%   9.84%
# 18   0.00%   0.00%   2.00%
# 19   1.20%   0.00%   0.24%
# 20   0.60%   0.00%   0.12%
# 21  36.14%   2.33%  31.08%
# 22   0.00%  16.28%   3.95%
# 23   6.02%   0.00%   4.43%
# 24  13.86%  13.95%  17.99%
# 25   2.41%  11.63%   8.05%
# 26  13.25%  13.95%   9.84%
# 27  58.43%  51.16%  58.78%
# 28   1.20%   0.00%   7.02%
# 29   0.00%   0.00%   3.16%
# 30   0.00%   2.33%   0.93%
# 31   7.83%   4.65%   4.59%
# 32   4.22%   0.00%   0.84%
# 33  47.59%  23.26%  59.58%
# 34  22.89%  34.88%  17.28%
# 35   3.01%   0.00%   0.83%
# 36  10.84%   9.30%  22.47%
# 37  59.64%  46.51%  45.17%
# 38   0.00%   2.33%   3.95%
# 39   1.20%   0.00%   3.73%
# 40   3.01%   0.00%   0.60%
# 41   0.60%   2.33%   0.59%

# %%
# Save the summary table to an Excel file
file_path = 'family_planning_history.xlsx'  # Save to the current directory in Colab
family_planning_table.to_excel(file_path, index=False, sheet_name="Summary Table")

# Automatically download the file
files.download(file_path)

# %% [markdown]
# ## Module 4: Family Planning Counselling

# %%
family_planning_counselling_variables = {
    'WNTMETH': 'When you came here today, did you want to receive a method of contraception from?',
    'SPCMTH': 'When you came here today, was there a specific FP method you wanted to get?',
    'WAMETH': 'Which method did you want to get when you came here today?',
    'RECMETH': 'Did you receive a method of contraception, or a referral to receive a method?',
    'CHMETH': 'Did you receive the method you wanted, or a referral for the method you wanted?',
    'METHNO': "What was the main reason you didn't receive a method or a referral for a method?",
    'CMREASON': 'You mentioned that you did not want or weren’t sure if you wanted a method of contraception?',
    'RECCOUN': 'Did the provider tell you about any potential side effects or problems you may experience?',
    'FOLLUP': 'Were you told what to do if you experience any side effects or problems as a result?',
    'CONTUSE': 'Were you told about the possibility of switching to another method if the method you selected was not suitable?',
    'OTHERMETH': 'Were you told by the provider about other methods of contraception besides the one chosen?'
}



variable_list = list(family_planning_counselling_variables.keys())
regions = ['Central', 'East', 'West', 'North', 'South']  # Specify regions

# Generate the summary table
family_planning_counselling_table = summary_percentage_table(
    data,
    variable_list,
    family_planning_counselling_variables,
    regions_column='REGION',
    regions=regions
)

# Display the result
family_planning_counselling_table
# Out:
#                                              Question  \
# 0   When you came here today, did you want to rece...
# 1   When you came here today, did you want to rece...
# 2   When you came here today, did you want to rece...
# 3   When you came here today, did you want to rece...
# 4   When you came here today, was there a specific...
# 5   When you came here today, was there a specific...
# 6   When you came here today, was there a specific...
# 7   Which method did you want to get when you came...
# 8   Which method did you want to get when you came...
# 9   Which method did you want to get when you came...
# 10  Which method did you want to get when you came...
# 11  Which method did you want to get when you came...
# 12  Which method did you want to get when you came...
# 13  Which method did you want to get when you came...
# 14  Which method did you want to get when you came...
# 15  Did you receive a method of contraception, or ...
# 16  Did you receive a method of contraception, or ...
# 17  Did you receive a method of contraception, or ...
# 18  Did you receive the method you wanted, or a re...
# 19  What was the main reason you didn't receive a ...
# 20  What was the main reason you didn't receive a ...
# 21  You mentioned that you did not want or weren’t...
# 22  You mentioned that you did not want or weren’t...
# 23  You mentioned that you did not want or weren’t...
# 24  You mentioned that you did not want or weren’t...
# 25  Did the provider tell you about any potential ...
# 26  Did the provider tell you about any potential ...
# 27  Did the provider tell you about any potential ...
# 28  Were you told what to do if you experience any...
# 29  Were you told what to do if you experience any...
# 30  Were you told what to do if you experience any...
# 31  Were you told about the possibility of switchi...
# 32  Were you told about the possibility of switchi...
# 33  Were you told by the provider about other meth...
# 34  Were you told by the provider about other meth...
# 35  Were you told by the provider about other meth...
#
#                                               Answers  Central     East  \
# 0                                                 Yes  100.00%  100.00%
# 1                                                  No    0.00%    0.00%
# 2                                          Don't know    0.00%    0.00%
# 3                                             Refused    0.00%    0.00%
# 4                                                 Yes  100.00%   90.00%
# 5                                                  No    0.00%   10.00%
# 6                                          Don't know    0.00%    0.00%
# 7                      Intra-uterine system or device   20.69%   10.00%
# 8                                            Implants   31.03%    0.00%
# 9                                 Contraceptive pills   13.79%   30.00%
# 10                                       Male condoms   24.14%   40.00%
# 11                            Emergency contraception    3.45%    0.00%
# 12                                        Injectables    6.90%   10.00%
# 13                                     Female condoms    0.00%    0.00%
# 14      Breast-feeding: lactational amenorrhea method    0.00%    0.00%
# 15                                                Yes   10.34%    0.00%
# 16                                                 No    0.00%   10.00%
# 17                                         Don't know    0.00%    0.00%
# 18                        Yes – got the method wanted  100.00%   90.00%
# 19                  I decided not to receive a method    0.00%   10.00%
# 20  The provider advised me to come back another d...    0.00%    0.00%
# 21                                       Changed mind    0.00%    0.00%
# 22                                         Don't know    0.00%    0.00%
# 23                    Felt pressured to take a method    0.00%    0.00%
# 24                                       Other reason    0.00%    0.00%
# 25                                                Yes  100.00%   90.00%
# 26                                                 No    0.00%    0.00%
# 27                                         Don't know    0.00%    0.00%
# 28                                                Yes  100.00%   90.00%
# 29                                                 No    0.00%    0.00%
# 30                                            Refused    0.00%    0.00%
# 31                                                Yes  100.00%   90.00%
# 32                                                 No    0.00%    0.00%
# 33                                                Yes  100.00%   90.00%
# 34                                                 No    0.00%    0.00%
# 35                                         Don't know    0.00%    0.00%
#
#       West   North   South   Total
# 0   94.19%  87.95%  93.02%  95.03%
# 1    4.65%  10.84%   6.98%   4.49%
# 2    1.16%   0.60%   0.00%   0.35%
# 3    0.00%   0.60%   0.00%   0.12%
# 4   91.86%  84.94%  79.07%  89.17%
# 5    2.33%   3.01%  11.63%   5.39%
# 6    0.00%   0.00%   2.33%   0.47%
# 7   20.93%   3.61%  11.63%  13.37%
# 8   11.63%  10.24%   4.65%  11.51%
# 9   26.74%  17.47%  11.63%  19.93%
# 10  27.91%  36.75%   9.30%  27.62%
# 11   0.00%   0.60%   4.65%   1.74%
# 12   4.65%  13.86%  23.26%  11.73%
# 13   0.00%   1.20%  13.95%   3.03%
# 14   0.00%   1.20%   0.00%   0.24%
# 15   1.16%   2.41%   6.98%   4.18%
# 16   0.00%   1.20%   0.00%   2.24%
# 17   0.00%   0.00%   2.33%   0.47%
# 18  91.86%  84.34%  79.07%  89.05%
# 19   0.00%   0.60%   0.00%   2.12%
# 20   0.00%   0.60%   0.00%   0.12%
# 21   2.33%   0.00%   0.00%   0.47%
# 22   1.16%   0.60%   0.00%   0.35%
# 23   0.00%   3.01%   0.00%   0.60%
# 24   0.00%   1.20%   0.00%   0.24%
# 25  68.60%  89.76%  88.37%  87.35%
# 26  29.07%   1.81%   0.00%   6.18%
# 27   0.00%   0.60%   2.33%   0.59%
# 28  73.26%  90.36%  90.70%  88.86%
# 29  24.42%   1.20%   0.00%   5.12%
# 30   0.00%   0.60%   0.00%   0.12%
# 31  84.88%  89.76%  88.37%  90.60%
# 32  12.79%   2.41%   2.33%   3.51%
# 33  90.70%  68.07%  90.70%  87.89%
# 34   6.98%  22.29%   0.00%   5.85%
# 35   0.00%   1.81%   0.00%   0.36%

# %%
# Save the summary table to an Excel file
file_path = 'family_planning_counselling_table.xlsx'  # Save to the current directory in Colab
family_planning_counselling_table.to_excel(file_path, index=False, sheet_name="Summary Table")

# Automatically download the file
files.download(file_path)

# %% [markdown]
# ##  Module 5: Client Experience
# - Identifying strategic goals:
# By evaluating current performance in
# client experience and client reach, CEI
# data can help identify opportunities
# to adapt or improve service delivery
# to maintain quality care and achieve
# further improvement.
# - Purpose: To understand what information
# the client received during
# their visit, how they felt about
# their interactions with staff
# and service providers, and
# their overall satisfaction with
# their visit.
# - Adaptation Considerations: Consider including questions that explore the information clients received, and client
# perceptions of the delivery and communication
# of this information.
#
# -  What is the experience of clients accessing
# your services? This can be answered by
# evaluating client experience questions,
# satisfaction scores, and client perception of the
# information provided about their services.

# %%
client_expereince_variables = {
    'REC': 'Based on your experience today, how likely are you to recommend our services to ',
    'RET': 'Based on your experience today, if you needed a similar service in the future, how likely is it that you would return to this site or provider? ',
    'HOURS': 'Was it clear to you what hours the facility was open/ when you could come to receive services today?',
    'FEED': 'Were you informed on how to give feedback or complain about your experience today?',
    'PRIVINFO': 'Do you trust the provider to keep your personal information private?',
    'PAIN_CM': 'Did the provider explain to you the possibility of experiencing pain during your',
    'PAINMAN_CM': ' Did the provider explain options for managing pain before your procedure?',
    'PAINOP_IMP': 'What options were explained to you?',
    'PAINOP_IMP1': 'Local anaesthesia',
    'PAINOP_IMP2': 'Medication for anxiety',
    'PAINOP_IMP3': 'Vocal local',
    'PAINOP_IMP666': 'Other',
    'PAINOP_IMP999': "Don't know",
    'PAINOP_IMP888': 'Refused',
    'PAINOP_IUD': 'What options were explained to you?',
    'PAINOP_IUD1': 'Oral analgesics',
    'PAINOP_IUD2': 'Local cream/spray on cervix',
    'PAINOP_IUD3': 'Paracervical block (injection next to the cervix)',
    'PAINOP_IUD4': 'Vocal local',
    'PAINOP_IUD666': 'Other',
    'PAINOP_IUD999': "Don't know",
    'PAINOP_IUD888': 'Refused',
    'MEDBEF_CM': 'Were you offered pain medication before the procedure?',
    'PAINSCALE_DCM': 'From 0-10, what was your pain during the procedure?',
    'PAINDUR_CM': 'Were you asked about pain during the procedure?',
    'MEDDUR_CM': 'Were you offered pain medication during the procedure?',
    'PAINSCALE_ACM': 'From 0-10, what was your pain after the procedure?',
    'PAINAFT_CM': 'Were you asked about pain after the procedure?',
    'MEDAFT_CM': 'Were you offered pain medication after the procedure?',
    'PAINRES_CM': 'Did you feel that the provider was respectful and responsive to your pain?',
}

variable_list = list(client_expereince_variables.keys())
regions = ['Central', 'East', 'West', 'North', 'South']  # Specify regions

# Generate the summary table
client_expereince_table = summary_percentage_table(
    data,
    variable_list,
    client_expereince_variables,
    regions_column='REGION',
    regions=regions
)

# Display the result
client_expereince_table
# Out:
#                                              Question                Answers  \
# 0   Based on your experience today, how likely are...  Promoter -Very Likely
# 1   Based on your experience today, how likely are...       Passive -Neutral
# 2   Based on your experience today, how likely are...    Detractor -unlikely
# 3   Based on your experience today, if you needed ...  Promoter -Very Likely
# 4   Based on your experience today, if you needed ...       Passive -Neutral
# ..                                                ...                    ...
# 85  Were you offered pain medication after the pro...                    Yes
# 86  Were you offered pain medication after the pro...                     No
# 87  Were you offered pain medication after the pro...             Don't know
# 88  Did you feel that the provider was respectful ...                    Yes
# 89  Did you feel that the provider was respectful ...                     No
#
#    Central     East    West   North   South   Total
# 0   86.21%  100.00%  89.53%  87.35%  39.53%  80.53%
# 1   10.34%    0.00%   5.81%   9.64%  53.49%  15.86%
# 2    0.00%    0.00%   4.65%   2.41%   6.98%   2.81%
# 3   96.55%  100.00%  88.37%  91.57%  46.51%  84.60%
# 4    3.45%    0.00%   5.81%   6.63%  34.88%  10.15%
# ..     ...      ...     ...     ...     ...     ...
# 85  44.83%   10.00%  32.56%  15.06%  16.28%  23.75%
# 86   3.45%    0.00%   1.16%   0.60%   0.00%   1.04%
# 87   0.00%    0.00%   0.00%   0.00%   2.33%   0.47%
# 88  48.28%   10.00%  32.56%  15.66%  18.60%  25.02%
# 89   0.00%    0.00%   1.16%   0.00%   0.00%   0.23%
#
# [90 rows x 8 columns]

# %%
# Save the summary table to an Excel file
file_path = 'client_expereince_table.xlsx'  # Save to the current directory in Colab
client_expereince_table.to_excel(file_path, index=False, sheet_name="Summary Table")

# Automatically download the file
files.download(file_path)

# %% [markdown]
# #### Client Statisfaction
# - 'PRIV': 'I had enough privacy during my visit today',
# - 'REST': 'I was treated with respect by all staff during my visit today',
# - 'WAIT': 'The time I waited to see a provider today was acceptable',
# - 'CARE': 'The provider was easy to understand ',
# - 'ENOUGH': 'The provider gave me enough information to make the best decisions about my meth',
# - 'SERIOUS': 'The provider took my preferences seriously ',
# - 'RPRT': 'The provider gave me the opportunity to explain my needs and ask questions ',
# - 'COMFORT': 'All staff members made me comfortable during my visit today',
# - 'GEN_SAT': 'Overall, how satisfied are you with your experience with us today?',

# %%
# I had enough privacy during my visit today

# Calculate total number of responses
total_responses = data.shape[0]

# Group by 'PRIV' and calculate percentage
enough_privacy = data.groupby('PRIV').size().reset_index(name='Count')
enough_privacy['Percentage'] = (enough_privacy['Count'] / total_responses) * 100

# Rename columns for clarity
enough_privacy = enough_privacy.rename(columns={'Percentage': '% of beneficiaries had enough privacy during their visit'})

# Display result
enough_privacy.sort_values(by='% of beneficiaries had enough privacy during their visit', ascending=True, inplace=True)

enough_privacy
# Out:
#                 PRIV  Count  \
# 3            Refused      1
# 2         Don't know      2
# 5  Strongly disagree      7
# 1           Disagree     61
# 4     Strongly agree    123
# 0              Agree    140
#
#    % of beneficiaries had enough privacy during their visit
# 3                                           0.299401
# 2                                           0.598802
# 5                                           2.095808
# 1                                          18.263473
# 4                                          36.826347
# 0                                          41.916168

# %%
plot_bar_chart_with_percentage(enough_privacy, 'PRIV', '% of beneficiaries had enough privacy during their visit', colors=colors)

# %%
# 'REST': 'I was treated with respect by all staff during my visit today'

# Group by 'PRIV' and calculate percentage
enough_privacy = data.groupby('REST').size().reset_index(name='Count')
enough_privacy['Percentage'] = (enough_privacy['Count'] / total_responses) * 100

# Rename columns for clarity
enough_privacy = enough_privacy.rename(columns={'Percentage': '% of beneficiaries treated with respect by all staff during their visit'})

# Display result
enough_privacy.sort_values(by='% of beneficiaries treated with respect by all staff during their visit', ascending=True, inplace=True)

enough_privacy
# Out:
#                          REST  Count  \
# 2                  Don't know      1
# 4                     Refused      1
# 6           Strongly disagree      1
# 1                    Disagree      2
# 3  Neither agree nor disagree      5
# 5              Strongly agree    148
# 0                       Agree    176
#
#    % of beneficiaries treated with respect by all staff during their visit
# 2                                           0.299401
# 4                                           0.299401
# 6                                           0.299401
# 1                                           0.598802
# 3                                           1.497006
# 5                                          44.311377
# 0                                          52.694611

# %%
plot_bar_chart_with_percentage(enough_privacy, 'REST', '% of beneficiaries treated with respect by all staff during their visit', colors=colors)

# %%
# Client Satisfaction Experience Questions
client_satisfaction_experience = {
    'PRIV': 'I had enough privacy during my visit today',
    'REST': 'I was treated with respect by all staff during my visit today',
    'WAIT': 'The time I waited to see a provider today was acceptable',
    'CARE': 'The provider was easy to understand',
    'ENOUGH': 'The provider gave me enough information to make the best decisions about my method',
    'SERIOUS': 'The provider took my preferences seriously',
    'RPRT': 'The provider gave me the opportunity to explain my needs and ask questions',
    'COMFORT': 'All staff members made me comfortable during my visit today',
    'GEN_SAT': 'Overall, how satisfied are you with your experience with us today?',
}

# %%
# 'PRIV': 'I had enough privacy during my visit today',

# Generate table
table = calculate_percentage_table(data, 'PRIV')
table.sort_values(by='% of beneficiaries for PRIV', ascending=True, inplace=True)

table
# Out:
#                 PRIV  Count  % of beneficiaries for PRIV
# 3            Refused      1                     0.299401
# 2         Don't know      2                     0.598802
# 5  Strongly disagree      7                     2.095808
# 1           Disagree     61                    18.263473
# 4     Strongly agree    123                    36.826347
# 0              Agree    140                    41.916168

# %%
# Plot chart
plot_bar_chart_with_percentage(table, 'PRIV', 'Count', colors=colors)

# %%
# REST: I was treated with respect by all staff during my visit today

# Generate table
table = calculate_percentage_table(data, 'REST')
table.sort_values(by='% of beneficiaries for REST', ascending=True, inplace=True)

table
# Out:
#                          REST  Count  % of beneficiaries for REST
# 2                  Don't know      1                     0.299401
# 4                     Refused      1                     0.299401
# 6           Strongly disagree      1                     0.299401
# 1                    Disagree      2                     0.598802
# 3  Neither agree nor disagree      5                     1.497006
# 5              Strongly agree    148                    44.311377
# 0                       Agree    176                    52.694611

# %%
# Plot chart
plot_bar_chart_with_percentage(table, 'REST', 'Count', colors=colors)

# %%
# 'WAIT': 'The time I waited to see a provider today was acceptable'

# Generate table
table = calculate_percentage_table(data, 'WAIT')
table.sort_values(by='% of beneficiaries for WAIT', ascending=True, inplace=True)
table
# Out:
#                          WAIT  Count  % of beneficiaries for WAIT
# 3           Strongly disagree      2                     0.598802
# 1  Neither agree nor disagree      6                     1.796407
# 2              Strongly agree    120                    35.928144
# 0                       Agree    206                    61.676647

# %%
# Plot chart
plot_bar_chart_with_percentage(table, 'WAIT', 'Count', colors=colors)

# %%
# 'CARE': 'The provider was easy to understand',

# Generate table
table = calculate_percentage_table(data, 'CARE')
table.sort_values(by='% of beneficiaries for CARE', ascending=True, inplace=True)
table
# Out:
#                          CARE  Count  % of beneficiaries for CARE
# 1                    Disagree      1                     0.299401
# 4           Strongly disagree      2                     0.598802
# 2  Neither agree nor disagree      5                     1.497006
# 3              Strongly agree    141                    42.215569
# 0                       Agree    185                    55.389222

# %%
# Plot chart
plot_bar_chart_with_percentage(table, 'CARE', 'Count', colors=colors)

# %%
# 'ENOUGH': 'The provider gave me enough information to make the best decisions about my method',

# Generate table
table = calculate_percentage_table(data, 'ENOUGH')
table.sort_values(by='% of beneficiaries for ENOUGH', ascending=True, inplace=True)
table
# Out:
#                        ENOUGH  Count  % of beneficiaries for ENOUGH
# 5           Strongly disagree      1                       0.299401
# 1                    Disagree      2                       0.598802
# 2                  Don't know      2                       0.598802
# 3  Neither agree nor disagree      6                       1.796407
# 4              Strongly agree    146                      43.712575
# 0                       Agree    177                      52.994012

# %%
# Plot chart
plot_bar_chart_with_percentage(table, 'ENOUGH', 'Count', colors=colors)

# %%
# 'SERIOUS': 'The provider took my preferences seriously',

# Generate table
table = calculate_percentage_table(data, 'SERIOUS')
table.sort_values(by='% of beneficiaries for SERIOUS', ascending=True, inplace=True)
table
# Out:
#                       SERIOUS  Count  % of beneficiaries for SERIOUS
# 5           Strongly disagree      1                        0.299401
# 1                    Disagree      2                        0.598802
# 2                  Don't know      2                        0.598802
# 3  Neither agree nor disagree      8                        2.395210
# 4              Strongly agree    124                       37.125749
# 0                       Agree    197                       58.982036

# %%
# Plot chart
plot_bar_chart_with_percentage(table, 'SERIOUS', 'Count', colors=colors)

# %%
# 'RPRT': 'The provider gave me the opportunity to explain my needs and ask questions',

# Generate table
table = calculate_percentage_table(data, 'RPRT')
table.sort_values(by='% of beneficiaries for RPRT', ascending=True, inplace=True)
table
# Out:
#                          RPRT  Count  % of beneficiaries for RPRT
# 4           Strongly disagree      3                     0.898204
# 1                    Disagree      4                     1.197605
# 2  Neither agree nor disagree      6                     1.796407
# 3              Strongly agree    131                    39.221557
# 0                       Agree    190                    56.886228

# %%
# Plot chart
plot_bar_chart_with_percentage(table, 'RPRT', 'Count', colors=colors)

# %%
# 'COMFORT': 'All staff members made me comfortable during my visit today'

# Generate table
table = calculate_percentage_table(data, 'COMFORT')
table.sort_values(by='% of beneficiaries for COMFORT', ascending=True, inplace=True)
table
# Out:
#                       COMFORT  Count  % of beneficiaries for COMFORT
# 4           Strongly disagree      2                        0.598802
# 1                    Disagree      3                        0.898204
# 2  Neither agree nor disagree      3                        0.898204
# 3              Strongly agree    130                       38.922156
# 0                       Agree    196                       58.682635

# %%
# Plot chart
plot_bar_chart_with_percentage(table, 'COMFORT', 'Count', colors=colors)

# %%
# 'GEN_SAT': 'Overall, how satisfied are you with your experience with us today?'

# Generate table
table = calculate_percentage_table(data, 'GEN_SAT')
table.sort_values(by='% of beneficiaries for GEN_SAT', ascending=True, inplace=True)
table
# Out:
#                  GEN_SAT  Count  % of beneficiaries for GEN_SAT
# 0                Refused      1                        0.299401
# 1  Somewhat dissatisfied      4                        1.197605
# 2     Somewhat satisfied     24                        7.185629
# 3         Very satisfied    305                       91.317365

# %%
# Plot chart
plot_bar_chart_with_percentage(table, 'GEN_SAT', 'Count', colors=colors)

# %% [markdown]
# ## 5. Marketing

# %%
marketing_variables = {
 'CCUSE_BEF': 'Did you speak to the MSI contact centre through phone or messaging at any point ',
 'CELLOWN': 'Do you have your own cell phone?',
}

# %%
variable_list = list(marketing_variables.keys())
regions = ['Central', 'East', 'West', 'North', 'South']

# Generate the summary table
marketing_table = summary_percentage_table(
    data,
    variable_list,
    marketing_variables,
    regions_column='REGION',
    regions=regions
)

# Display the result
marketing_table
# Out:
#                                             Question     Answers Central  \
# 0  Did you speak to the MSI contact centre throug...         Yes  58.62%
# 1  Did you speak to the MSI contact centre throug...          No  41.38%
# 2                   Do you have your own cell phone?          No  48.28%
# 3                   Do you have your own cell phone?         Yes  51.72%
# 4                   Do you have your own cell phone?  Don't know   0.00%
#
#      East    West   North    South   Total
# 0  40.00%   3.49%  23.49%    0.00%  25.12%
# 1  60.00%  96.51%  76.51%  100.00%  74.88%
# 2  40.00%   3.49%  19.88%   97.67%  41.86%
# 3  60.00%  96.51%  79.52%    2.33%  58.02%
# 4   0.00%   0.00%   0.60%    0.00%   0.12%

# %%
def calculate_top_bottom_responses(data, column, top_n=5):
    """
    Calculate percentages for a given column and return the top N most common responses
    and the least common response.
    """
    total_responses = data.shape[0]

    # Count and calculate percentage
    percentage_table = data.groupby(column).size().reset_index(name='Count')
    percentage_table['Percentage'] = (percentage_table['Count'] / total_responses) * 100
    percentage_table = percentage_table.rename(columns={'Percentage': f'% of beneficiaries for {column}'})

    # Get top N most common responses
    top_responses = percentage_table.nlargest(top_n, 'Count')

    return top_responses

def plot_top_bottom_chart(data, column, label, top_n=12):
    """
    Plot a horizontal bar chart for the top N responses and least common response.
    """
    percentage_table = calculate_top_bottom_responses(data, column, top_n)

    # Plot
    plt.figure(figsize=(10, 6))
    bars = plt.barh(percentage_table[column], percentage_table[f'% of beneficiaries for {column}'], color=colors)

    # Remove border (spines)
    for spine in plt.gca().spines.values():
        spine.set_visible(False)

    # Add percentage labels
    for bar in bars:
        width = bar.get_width()
        plt.text(width + 1, bar.get_y() + bar.get_height()/2, f"{width:.1f}%",
                 ha='left', va='center', fontsize=12, color='black')

    # Formatting
    plt.grid(axis='x', linestyle='--', alpha=0.5)

    # Show plot
    plt.show()

# %%
# Did any of the following play a part in making you aware of the services you received today, or influence your decision to visit today?

info_labels = {
    'IADVERT': 'TV advert or programme',
    'IRADIO': 'Radio advert or programme',
    'INEWS': 'Newspaper/ magazine',
    'IMEET': 'Community meeting or event',
    'INET': 'Website/ Google',
    'ISOCMED': 'Social media',
    'ISIGN': 'Outdoor sign',
    'ISPKR': 'Loudspeaker',
    'IPRMAT': 'Posters/ leaflets / flyers',
    'MSAFG_IRELG': 'Religious Leaders/Groups',
    'INFOOTH': 'Other',
    'INFONO': 'None'
}

info_table = calculate_top_bottom_responses(original_data, 'INFO')
info_table
# Out:
#        INFO  Count  % of beneficiaries for INFO
# 26  INFOOTH     67                    20.059880
# 39    ISIGN     45                    13.473054
# 0   IADVERT     41                    12.275449
# 44    ISPKR     31                     9.281437
# 25   INFONO     29                     8.682635

# %%
plot_top_bottom_chart(data, 'INFO', "Top and Least Common Factors Influencing Visit")

# %%
social_community_context = {
     'POSIPC': 'In my community, I hear positive stories about using contraception',
 'KSANCTION': 'In my community, women are stigmatised if people know that they use contraceptio',
 'KMENSUPP': 'In my community, most men are supportive of their partner(s) using contraception',
 'KCOMSUPP': 'In my community, using modern contraception is accepted',
 'KLEADSUP': 'In my community, local leaders encourage the use of contraception',
 'FPDECMAK': 'Who usually makes decisions about any methods of contraception for yourself?',

}

variable_list = list(social_community_context.keys())  # Replace with your list of questions
regions = ['Central', 'East', 'West', 'North', 'South']  # Specify regions

# Generate the summary table
social_community_context_table = summary_percentage_table(
    data,
    variable_list,
    social_community_context,
    regions_column='REGION',
    regions=regions
)

# Display the result
social_community_context_table
# Out:
#                                              Question  \
# 0   In my community, I hear positive stories about...
# 1   In my community, I hear positive stories about...
# 2   In my community, I hear positive stories about...
# 3   In my community, I hear positive stories about...
# 4   In my community, I hear positive stories about...
# 5   In my community, I hear positive stories about...
# 6   In my community, I hear positive stories about...
# 7   In my community, women are stigmatised if peop...
# 8   In my community, women are stigmatised if peop...
# 9   In my community, women are stigmatised if peop...
# 10  In my community, women are stigmatised if peop...
# 11  In my community, women are stigmatised if peop...
# 12  In my community, women are stigmatised if peop...
# 13  In my community, women are stigmatised if peop...
# 14  In my community, most men are supportive of th...
# 15  In my community, most men are supportive of th...
# 16  In my community, most men are supportive of th...
# 17  In my community, most men are supportive of th...
# 18  In my community, most men are supportive of th...
# 19  In my community, most men are supportive of th...
# 20  In my community, using modern contraception is...
# 21  In my community, using modern contraception is...
# 22  In my community, using modern contraception is...
# 23  In my community, using modern contraception is...
# 24  In my community, using modern contraception is...
# 25  In my community, using modern contraception is...
# 26  In my community, local leaders encourage the u...
# 27  In my community, local leaders encourage the u...
# 28  In my community, local leaders encourage the u...
# 29  In my community, local leaders encourage the u...
# 30  In my community, local leaders encourage the u...
# 31  In my community, local leaders encourage the u...
# 32  In my community, local leaders encourage the u...
# 33  Who usually makes decisions about any methods ...
# 34  Who usually makes decisions about any methods ...
# 35  Who usually makes decisions about any methods ...
#
#                                    Answers  Central    East    West   North  \
# 0                           Strongly agree   75.86%  30.00%  31.40%  36.14%
# 1                                    Agree   24.14%  70.00%  52.33%  62.05%
# 2                        Strongly disagree    0.00%   0.00%   2.33%   0.60%
# 3                                 Disagree    0.00%   0.00%   4.65%   0.00%
# 4               Neither agree nor disagree    0.00%   0.00%   9.30%   0.00%
# 5                               Don't know    0.00%   0.00%   0.00%   1.20%
# 6                                  Refused    0.00%   0.00%   0.00%   0.00%
# 7                                 Disagree   58.62%   0.00%  17.44%  37.35%
# 8                               Don't know   34.48%   0.00%   5.81%  21.69%
# 9                                    Agree    3.45%  90.00%  53.49%  17.47%
# 10                          Strongly agree    0.00%  10.00%  12.79%   4.22%
# 11              Neither agree nor disagree    0.00%   0.00%   9.30%  15.66%
# 12                       Strongly disagree    0.00%   0.00%   1.16%   3.61%
# 13                                 Refused    3.45%   0.00%   0.00%   0.00%
# 14                          Strongly agree   79.31%  80.00%  23.26%  41.57%
# 15                                   Agree   20.69%  20.00%  56.98%  56.63%
# 16                                Disagree    0.00%   0.00%   5.81%   0.60%
# 17                       Strongly disagree    0.00%   0.00%   2.33%   0.60%
# 18                              Don't know    0.00%   0.00%   0.00%   0.60%
# 19              Neither agree nor disagree    0.00%   0.00%  11.63%   0.00%
# 20                                   Agree   48.28%  70.00%   2.33%  42.17%
# 21                          Strongly agree   31.03%  20.00%   0.00%  18.67%
# 22                              Don't know   20.69%   0.00%  43.02%  17.47%
# 23                                Disagree    0.00%  10.00%  18.60%  10.24%
# 24                       Strongly disagree    0.00%   0.00%   1.16%   1.81%
# 25              Neither agree nor disagree    0.00%   0.00%  34.88%   9.64%
# 26                                   Agree   62.07%  80.00%   8.14%  29.52%
# 27                          Strongly agree   17.24%  20.00%   1.16%  11.45%
# 28                              Don't know   20.69%   0.00%  20.93%  18.67%
# 29                                Disagree    0.00%   0.00%  48.84%  19.28%
# 30                       Strongly disagree    0.00%   0.00%   3.49%   1.20%
# 31              Neither agree nor disagree    0.00%   0.00%  10.47%  19.88%
# 32                                 Refused    0.00%   0.00%   6.98%   0.00%
# 33  You and your husband / partner jointly  100.00%  10.00%  62.79%  89.76%
# 34                  Your husband / partner    0.00%  90.00%  32.56%   7.23%
# 35                            You yourself    0.00%   0.00%   4.65%   3.01%
#
#      South   Total
# 0    0.00%  34.68%
# 1   65.12%  54.73%
# 2    0.00%   0.59%
# 3    0.00%   0.93%
# 4    0.00%   1.86%
# 5   25.58%   5.36%
# 6    9.30%   1.86%
# 7    4.65%  23.61%
# 8   32.56%  18.91%
# 9   58.14%  44.51%
# 10   0.00%   5.40%
# 11   0.00%   4.99%
# 12   2.33%   1.42%
# 13   2.33%   1.15%
# 14   2.33%  45.29%
# 15  69.77%  44.81%
# 16   0.00%   1.28%
# 17   0.00%   0.59%
# 18  27.91%   5.70%
# 19   0.00%   2.33%
# 20  65.12%  45.58%
# 21   4.65%  14.87%
# 22  30.23%  22.28%
# 23   0.00%   7.77%
# 24   0.00%   0.59%
# 25   0.00%   8.90%
# 26  34.88%  42.92%
# 27   4.65%  10.90%
# 28  55.81%  23.22%
# 29   2.33%  14.09%
# 30   0.00%   0.94%
# 31   2.33%   6.53%
# 32   0.00%   1.40%
# 33   0.00%  52.51%
# 34  46.51%  35.26%
# 35  53.49%  12.23%

# %%
# Save the summary table to an Excel file
file_path = 'social_community_context_table.xlsx'  # Save to the current directory in Colab
social_community_context_table.to_excel(file_path, index=False, sheet_name="Summary Table")

# Automatically download the file
files.download(file_path)

# %% [markdown]
# # Inferrential Analysis

# %% [markdown]
# 1. Chi-Square Test for Association
# - Purpose: To determine if there is a significant relationship between categorical variables.
# - Examples:
#  1. Association between contraceptive method received (FPreceived) and client satisfaction (GEN_SAT).
#  2. Relationship between education level (EDU) and contraceptive use history (FPEVER).
# Whether gender (GENDER) influences pain perception (PAINSCALE_DREM, PAINSCALE_ACM).

# %%
contraceptive_client = data.groupby(['FPreceived', 'GEN_SAT']).size().reset_index(name='frequency')

# %%
contraceptive_client
# Out:
#    FPreceived                GEN_SAT  frequency
# 0          EC         Very satisfied          3
# 1       EC MC         Very satisfied          1
# 2          FC         Very satisfied          7
# 3       FC MC         Very satisfied          1
# 4         IMP                Refused          1
# 5         IMP     Somewhat satisfied          1
# 6         IMP         Very satisfied         34
# 7         INJ  Somewhat dissatisfied          1
# 8         INJ     Somewhat satisfied          3
# 9         INJ         Very satisfied         37
# 10     INJ MC         Very satisfied          2
# 11        IUD  Somewhat dissatisfied          1
# 12        IUD     Somewhat satisfied          6
# 13        IUD         Very satisfied         32
# 14         MC  Somewhat dissatisfied          1
# 15         MC     Somewhat satisfied          7
# 16         MC         Very satisfied         80
# 17      MC EC         Very satisfied          3
# 18  MC EC INJ         Very satisfied          1
# 19     MC INJ         Very satisfied          2
# 20         OC     Somewhat satisfied          3
# 21         OC         Very satisfied         66
# 22      OC EC         Very satisfied          1
# 23      OC MC         Very satisfied          1
# 24        REF     Somewhat satisfied          1
# 25        REF         Very satisfied          2

# %%
# Pivot the table to create a contingency table

contengency_table = pd.pivot_table(contraceptive_client, values='frequency',
                                   index='FPreceived',
                                   columns='GEN_SAT',
                                   aggfunc='sum',
                                   fill_value=0)

# %%
contengency_table
# Out:
# GEN_SAT     Refused  Somewhat dissatisfied  Somewhat satisfied  Very satisfied
# FPreceived
# EC                0                      0                   0               3
# EC MC             0                      0                   0               1
# FC                0                      0                   0               7
# FC MC             0                      0                   0               1
# IMP               1                      0                   1              34
# INJ               0                      1                   3              37
# INJ MC            0                      0                   0               2
# IUD               0                      1                   6              32
# MC                0                      1                   7              80
# MC EC             0                      0                   0               3
# MC EC INJ         0                      0                   0               1
# MC INJ            0                      0                   0               2
# OC                0                      0                   3              66
# OC EC             0                      0                   0               1
# OC MC             0                      0                   0               1
# REF               0                      0                   1               2

# %%
# Perform the Chi-Square test for association
from scipy.stats import chi2_contingency

chi2, p, dof, expected = chi2_contingency(contengency_table)

# %%
# Display results
print("Chi-Square Statistic:", chi2)
print("Degrees of Freedom:", dof)
print("Expected Frequencies:")
print(expected)
print("P-Value:", p)
# Out:
# Chi-Square Statistic: 21.39647357503626
# Degrees of Freedom: 45
# Expected Frequencies:
# [[1.00671141e-02 3.02013423e-02 2.11409396e-01 2.74832215e+00]
#  [3.35570470e-03 1.00671141e-02 7.04697987e-02 9.16107383e-01]
#  [2.34899329e-02 7.04697987e-02 4.93288591e-01 6.41275168e+00]
#  [3.35570470e-03 1.00671141e-02 7.04697987e-02 9.16107383e-01]
#  [1.20805369e-01 3.62416107e-01 2.53691275e+00 3.29798658e+01]
#  [1.37583893e-01 4.12751678e-01 2.88926174e+00 3.75604027e+01]
#  [6.71140940e-03 2.01342282e-02 1.40939597e-01 1.83221477e+00]
#  [1.30872483e-01 3.92617450e-01 2.74832215e+00 3.57281879e+01]
#  [2.95302013e-01 8.85906040e-01 6.20134228e+00 8.06174497e+01]
#  [1.00671141e-02 3.02013423e-02 2.11409396e-01 2.74832215e+00]
#  [3.35570470e-03 1.00671141e-02 7.04697987e-02 9.16107383e-01]
#  [6.71140940e-03 2.01342282e-02 1.40939597e-01 1.83221477e+00]
#  [2.31543624e-01 6.94630872e-01 4.86241611e+00 6.32114094e+01]
#  [3.35570470e-03 1.00671141e-02 7.04697987e-02 9.16107383e-01]
#  [3.35570470e-03 1.00671141e-02 7.04697987e-02 9.16107383e-01]
#  [1.00671141e-02 3.02013423e-02 2.11409396e-01 2.74832215e+00]]
# P-Value: 0.9989101471881987

# %%
# Interpretation
if p < 0.05:
    print("There is a significant association between Contraceptive Method and Satisfaction.")
else:
    print("There is no significant association between Contraceptive Method and Satisfaction.")
# Out:
# There is no significant association between Contraceptive Method and Satisfaction.

# %%
original_data['WAIT'].unique()
# Out:
# array(['Strongly agree', 'Agree', 'Neither agree nor disagree',
#        'Strongly disagree'], dtype=object)

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# Create a contingency table for EDUCATION and METHOD USED
contingency_table = pd.crosstab(data['EDU'], data['FPreceived'])

# Perform the Chi-Square Test
chi2, p_value, dof, expected = chi2_contingency(contingency_table)

# %%
contingency_table
# Out:
# FPreceived                                    EC  EC MC  FC  FC MC  IMP  INJ  \
# EDU
# Completed primary                              0      0   0      0    4    1
# Completed secondary, vocational or technical   0      1   0      0    2    0
# None / non-formal                              2      0   7      0   20   29
# Some primary                                   0      0   0      0    4    7
# Some secondary, vocational or technical        1      0   0      0    1    1
# Some tertiary or higher                        0      0   0      1    5    3
#
# FPreceived                                    INJ MC  IUD  MC  MC EC  \
# EDU
# Completed primary                                  0   11  12      0
# Completed secondary, vocational or technical       0    2   4      0
# None / non-formal                                  1   20  55      3
# Some primary                                       1    2  14      0
# Some secondary, vocational or technical            0    2   1      0
# Some tertiary or higher                            0    2   2      0
#
# FPreceived                                    MC EC INJ  MC INJ  OC  OC EC  \
# EDU
# Completed primary                                     0       0  12      0
# Completed secondary, vocational or technical          0       0   3      1
# None / non-formal                                     0       2  34      0
# Some primary                                          1       0  16      0
# Some secondary, vocational or technical               0       0   1      0
# Some tertiary or higher                               0       0   3      0
#
# FPreceived                                    OC MC  REF
# EDU
# Completed primary                                 0    0
# Completed secondary, vocational or technical      0    0
# None / non-formal                                 0    3
# Some primary                                      0    0
# Some secondary, vocational or technical           1    0
# Some tertiary or higher                           0    0

# %%
# Print the results
print("\nChi-Square Test Results:")
print(f"Chi-Square Value: {chi2}")
print(f"P-Value: {p_value}")
print(f"Degrees of Freedom: {dof}")

# Interpretation of results
if p_value < 0.05:
    print("\nThere is a significant association between education level and methods used.")
else:
    print("\nThere is no significant association between education level and methods used.")
# Out:
# Chi-Square Test Results:
# Chi-Square Value: 158.24585986834632
# P-Value: 6.805783492385852e-08
# Degrees of Freedom: 75
#
# There is a significant association between education level and methods used.

# %% [markdown]
# ## The Relationship Between Education Level and Contraceptive Methods Used
# ###Background
# In this study, we examine whether there is a significant association between a person’s education level and the type of contraceptive methods they use. We hypothesize that individuals with higher education levels are more likely to use modern contraceptive methods due to increased access to information, healthcare, and an understanding of family planning.
#
# - The dataset includes two key variables:
#
#  - EDU (Education Level): Categories such as "Completed primary," "Some primary," "Completed secondary, vocational or technical," "Some tertiary or higher," and "None / non-formal."
#  - FPreceived (Contraceptive Methods Used): Various contraceptive methods, such as "EC" (Emergency Contraception), "IUD" (Intrauterine Device), "OC" (Oral Contraceptives), "FC" (Female Condom), "IMP" (Injectable), and others.
#
# ### Key Observations from the Contingency Table
# The contingency table provides several important insights:
#
# 1. Higher Education Levels and Use of Modern Contraceptive Methods:
#  - Individuals with higher education levels (e.g., "Some tertiary or higher") tend to use more modern contraceptive methods, such as "IUD" and "OC," as seen in the table.
#  - The "Completed secondary, vocational or technical" and "Some tertiary or higher" groups show usage of methods like "IUD" and "OC," indicating a preference for more effective and modern contraceptive options.
# 2. Lower Education Levels and Use of Traditional Methods:
#  - The "None / non-formal" group shows a relatively high frequency of contraceptive use, but with a mix of methods such as "EC" (Emergency Contraception), "FC" (Female Condom), and "IMP" (Injectable). This suggests that people in this group may have less access to modern contraceptive methods or may be using a wider variety of methods for different needs.
# 3. Intermediate Education Levels:
#  - Groups such as "Some primary" and "Some secondary, vocational or technical" use methods like "IMP," "INJ," and "MC" (Modern Contraceptives), but they show less diversity in contraceptive use compared to those with higher education. These groups may still rely on traditional or less effective methods more than individuals with higher education.
#
# ## Interpretation
# The results of the Chi-Square test and the analysis of the contingency table support the hypothesis that education level influences the choice of contraceptive methods. The following key points can be drawn from the findings:
#
#  - Access to Information: People with higher education levels are likely to have better access to family planning information and healthcare, which might explain their preference for modern contraceptive methods.
#
# - Healthcare Access and Decision Making: Education can empower individuals to make informed decisions about reproductive health. Those with higher education are likely more aware of the long-term benefits and risks associated with different methods of contraception.
#
# - Targeted Interventions: The data suggests that targeted family planning interventions may be needed for individuals with lower levels of education to ensure they have access to modern contraceptive options. These interventions could focus on improving awareness, access, and affordability of modern contraception methods.
